# %%
from gwsnr import GWSNR

psd_end_time = 1126259462.4-4.0 
gwsnr = GWSNR(psds={'L1':psd_end_time, 'H1':psd_end_time})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/ripple1/lib/python3.10/site-packages/gwosc/api.py:62, in fetch_json(url, **kwargs)
#      61 try:
# ---> 62     return JSON_CACHE[url]
#      63 except KeyError:
#
# KeyError: 'https://gwosc.org/eventapi/jsonfull/allevents/'
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# ...
