# %%
import numpy as np
import matplotlib.pyplot as plt

from ler import LeR

# %%
ler = LeR()
# Out:
# /Users/phurailatpamhemantakumar/anaconda3/envs/lerenv/lib/python3.10/site-packages/ler/source_population.py:174: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   self.normalization_pdf_z = quad(pdf_unnormalized, z_min, z_max)[0]
# /Users/phurailatpamhemantakumar/anaconda3/envs/lerenv/lib/python3.10/site-packages/ler/lens_galaxy_population.py:225: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   self.normalization_pdf_z = quad(pdf_unnormalized, self.z_min, self.z_max)[0]
# Given: IMR waveform, {self.waveform_approximant}.
# psds not given. Choosing bilby's default psds
# given psds:  {'L1': 'aLIGO_O4_high_asd.txt', 'H1': 'aLIGO_O4_high_asd.txt', 'V1': 'AdV_asd.txt'}
# Interpolator will be generated for L1 detector at ./interpolator_pickle/L1/halfSNR_dict_6.pickle
# Interpolator will be generated for H1 detector at ./interpolator_pickle/H1/halfSNR_dict_6.pickle
# Interpolator will be generated for V1 detector at ./interpolator_pickle/V1/halfSNR_dict_6.pickle
# Generating interpolator for ['L1', 'H1', 'V1'] detectors
# interpolation for each mass_ratios: 100%|███████████████████████████| 50/50 [00:06<00:00,  7.95it/s]
# interpolator generated

# %%
ler.batch_size = 50000
gw_param = ler.unlensed_cbc_statistics(nsamples=100000)
# Out:
# chosen batch size = 50000. If you want to change batch size, self.batch_size = new_size
# There will be 2 batche(s)
# Batch no. 1
# sampling gw source params...
# calculating snrs...
# Batch no. 2
# sampling gw source params...
# calculating snrs...

# %%
gw_param.keys()
# Out:
# dict_keys(['mass_1', 'mass_2', 'mass_1_source', 'mass_2_source', 'zs', 'luminosity_distance', 'iota', 'psi', 'phase', 'geocent_time', 'ra', 'dec', 'a_1', 'a_2', 'tilt_1', 'tilt_2', 'phi_12', 'phi_jl', 'opt_snr_net', 'L1', 'H1', 'V1'])

# %%
plt.hist(gw_param["zs"], bins=100, density=True, histtype="step", label="GW")
plt.show()

# %%
plt.hist(gw_param['mass_1_source'], bins=100, density=True, histtype="step", label="GW")
plt.hist(gw_param['mass_2_source'], bins=100, density=True, histtype="step", label="GW")
plt.xlim(0, 50)
plt.show()
