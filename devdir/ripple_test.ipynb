# %% [markdown]
# ## Supported waveforms:
#
# * IMRPhenomXAS (aligned spin): theta = [Mchirp, eta, chi1, chi2, D, tc, phic]
# * IMRPhenomD (aligned spin): theta = [Mchirp, eta, chi1, chi2, D, tc, phic]
# * IMRPhenomPv2 (Still finalizing sampling checks): not known
# * TaylorF2 with tidal effects : [Mchirp, eta, chi1, chi2, lambda1, lambda2, D, tc, phic]
#   * lambda1: Dimensionless tidal deformability of the primary object [between 0 and 5000]
#   * lambda2: Dimensionless tidal deformability of the secondary object [between 0 and 5000]
# * IMRPhenomD_NRTidalv2, verified for the low spin regime (chi1, chi2 < 0.05), further testing is required for higher spins: [Mchirp, eta, chi1, chi2, lambda1, lambda2, D, tc, phic, inclination]
#
# ## Parameters:
#
# * Mchirp: Chirp mass of the system [solar masses]
# * eta: Symmetric mass ratio [between 0.0 and 0.25]
# * chi1: Dimensionless aligned spin of the primary object [between -1 and 1]
# * chi2: Dimensionless aligned spin of the secondary object [between -1 and 1]
# * lambda1: Dimensionless tidal deformability of the primary object [between 0 and 5000]
# * lambda2: Dimensionless tidal deformability of the secondary object [between 0 and 5000]
# * D: Luminosity distance to source [Mpc]
# * tc: Time of coalesence. This only appears as an overall linear in f contribution to the phase
# * phic: Phase of coalesence
# * inclination: Inclination angle of the binary [between 0 and PI]

# %%
import jax.numpy as jnp
import numpy as np
import bilby
#from ripple.waveforms import IMRPhenomD
from ripple import ms_to_Mc_eta
from jax import vmap
from jax import jit
from gwsnr import noise_weighted_inner_product

# %%
from gwsnr import RippleInnerProduct
#from gwsnr import findchirp_chirptime_jax

# %%
import numpy as np
size = 10

gw_param_dict = {
    "mass_1": np.random.uniform(10,50,size),
    "mass_2": np.random.uniform(10,50,size),
    "luminosity_distance": 440*np.ones(size),
    "theta_jn": 0.0*np.ones(size),
    "psi": 0.659*np.ones(size),
    "phase": 0.0*np.ones(size),
    "geocent_time": 0.*np.ones(size),
    "ra": 1.375*np.ones(size),
    "dec": -1.2108*np.ones(size),
    "a_1": 0.5*np.ones(size),
    "a_2": -0.5*np.ones(size),
    "tilt_1": 0.0*np.ones(size),
    "tilt_2": 0.0*np.ones(size),
    "phi_12": 0.0*np.ones(size),
    "phi_jl": 0.0*np.ones(size),
}

idx = (gw_param_dict['mass_1'] < gw_param_dict['mass_2'])
gw_param_dict['mass_1'][idx], gw_param_dict['mass_2'][idx] = gw_param_dict['mass_2'][idx], gw_param_dict['mass_1'][idx]

# %%
test = RippleInnerProduct('IMRPhenomD')

# %%
from gwsnr import GWSNR

gwsnr = GWSNR(npool=4, snr_type='inner_product_jax', gwsnr_verbose=False, ifos=['L1', 'H1', 'V1'], multiprocessing_verbose=True)

# %%
# size=100000, 4m 18.2s
ans = test.noise_weighted_inner_product_jax(gw_param_dict, gwsnr.psds_list, gwsnr.detector_list, multiprocessing_verbose=True)
# Out:
# 100%|██████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 257.85it/s]

# %%
# size=100000, time=50.7s
ans2 = gwsnr.snr(gw_param_dict=gw_param_dict)
ans2
# Out:
# solving SNR with inner product JAX
# 100%|███████████████████████████████████████████████████████████████| 10/10 [00:03<00:00,  3.06it/s]
# {'L1': array([66.04323701, 59.20393426, 42.74319364, 41.98536111, 28.78254717,
#         43.76257075, 55.9290411 , 49.92542936, 61.99139003, 38.79745521]),
#  'H1': array([87.19084117, 78.16153572, 56.42992646, 55.42942953, 37.99896269,
#         57.77571676, 73.83799402, 65.91197493, 81.84155845, 51.22072915]),
#  'V1': array([53.5713521 , 48.05895552, 34.95451127, 34.23742383, 22.95812389,
#         35.76835162, 45.43122714, 40.76172455, 50.30093562, 31.6269057 ]),
#  'optimal_snr_net': array([121.79425973, 109.1970453 ,  78.95020621,  77.5073764 ,
#          52.90965545,  80.82432198, 103.17026412,  92.18706593,
#         114.32916185,  71.61750337])}

# %%
gwsnr = GWSNR(npool=4, snr_type='inner_product', gwsnr_verbose=False, ifos=['L1', 'H1', 'V1'], multiprocessing_verbose=True)
ans3 = gwsnr.snr(gw_param_dict=gw_param_dict)
ans3
# Out:
# solving SNR with inner product
# 100%|███████████████████████████████████████████████████████████████| 10/10 [00:03<00:00,  3.04it/s]
# {'L1': array([66.04311361, 59.20373333, 42.74315353, 41.98536447, 28.78253705,
#         43.76249461, 55.92884469, 49.92547396, 61.991195  , 38.79744863]),
#  'H1': array([87.19067826, 78.16127045, 56.42987351, 55.42943397, 37.99894932,
#         57.77561623, 73.83773471, 65.9120338 , 81.84130097, 51.22072047]),
#  'V1': array([53.57124489, 48.05878205, 34.95447256, 34.23742383, 22.95811577,
#         35.76827529, 45.4310542 , 40.76176521, 50.30077473, 31.62689902]),
#  'optimal_snr_net': array([121.79402904, 109.19667015,  78.95012951,  77.50738139,
#          52.90963682,  80.82417511, 103.16989591,  92.18715015,
#         114.328801  ,  71.61749065])}

# %%
hp = ans[0][0]
hc = ans[0][1]
fs = ans[0][2]
fsize_arr = ans[0][3]
fmin = ans[0][4]
duration = ans[0][5]
psd_object = ans[0][7][0]

hp = np.array(hp[:fsize_arr], dtype=np.complex128)
hc = np.array(hc[:fsize_arr], dtype=np.complex128)
# find the index of 20Hz or nearby
# set all elements to zero below this index
fs =  fs[:fsize_arr]
idx = np.abs( fs - fmin).argmin()
hp[:idx] = 0.0 + 0.0j
hc[:idx] = 0.0 + 0.0j

psd_array = psd_object.get_power_spectral_density_array(fs)

# %%
signal1 = jnp.array(hp, dtype=np.complex128)
signal2 = jnp.array(hc, dtype=np.complex128)
psd = jnp.array(psd_array)
# duration
np.conj(signal1) * signal2 /psd
# Out:
# /var/folders/ws/0948zvwd7g795j2l3fryghjw0000gp/T/ipykernel_26111/1123133259.py:1: UserWarning: Explicitly requested dtype <class 'numpy.complex128'> requested in array is not available, and will be truncated to dtype complex64. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   signal1 = jnp.array(hp, dtype=np.complex128)
# /var/folders/ws/0948zvwd7g795j2l3fryghjw0000gp/T/ipykernel_26111/1123133259.py:2: UserWarning: Explicitly requested dtype <class 'numpy.complex128'> requested in array is not available, and will be truncated to dtype complex64. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   signal2 = jnp.array(hc, dtype=np.complex128)
# Array([ 0. +0.j,  0. +0.j,  0. +0.j, ..., nan+nanj, nan+nanj, nan+nanj],      dtype=complex64)

# %%
signal1 = hp
signal2 = hc
psd = psd_array
# duration
np.conj(signal1) * signal2 /psd
# Out:
# array([0.+0.00000000e+00j, 0.+0.00000000e+00j, 0.+0.00000000e+00j, ...,
#        0.-6.13156915e-10j, 0.-6.09602254e-10j, 0.-6.06050285e-10j])

# %%
from numba import njit
from jax import jit

@jit
def noise_weighted_inner_product(
    signal1, signal2, psd, duration,
):
    nwip_arr = np.conj(signal1) * signal2 / psd
    return 4 / duration * np.sum(nwip_arr)

# %%
siz2 = 2
hp = np.array([[1,2,3],[4,5,6]])
hc = np.array([[7,8,9],[10,11,12]])
fs = np.array([[13,14,15],[16,17,18]])
iter = np.arange(size)
list_ = []
for i in range(size):
    list_.append([hp[0], hc[0], fs[0], iter[0]])

# %%
np.array(list_, dtype=object)[0]
# Out:
# array([array([1, 2, 3]), array([7, 8, 9]), array([13, 14, 15]), 0],
#       dtype=object)

# %%
input_arguments[0].shape, hp.shape
# Out:
# ((3, 2), (2, 3))

# %%
test2 = np.concatenate((ans[0], ans[1]), axis=1)

# %%
test2[0].shape
# Out:
# (18434,)

# %%
# set up psd
psd_dict = psd_dict.copy()
for key, value in psd_dict.items(): # key is the detector name
    if not isinstance(value, bilby.gw.detector.PowerSpectralDensity):
        raise ValueError(f"Expected bilby.gw.detector.PowerSpectralDensity object for {key} in psd_dict")
    # compute the power spectral density array according to the frequency array
    psd_list = []
    fs_ = []
    for i in range(size):
        fs_.append(fs[i][:fsize_arr[i]])  # avoid np.nan paddings
        psd_list.append(psd_dict[key].get_power_spectral_density_array(fs_[i]))
    psd_dict[key] = np.array(psd_list, dtype=object)
    fs = np.array(fs_, dtype=object)

# set up h+,hx for inner_product
hp_, hc_ = [], []
for i in range(size):
    # remove the np.nan padding
    hp_.append(np.array(hp[i][:fsize_arr[i]], dtype=np.complex128))
    hc_.append(np.array(hc[i][:fsize_arr[i]], dtype=np.complex128))
    # find the index of 20Hz or nearby
    # set all elements to zero below this index
    idx = np.abs(fs[i] - self.f_l).argmin()
    hp_[i][0:idx] = 0.0 + 0.0j
    hc_[i][0:idx] = 0.0 + 0.0j
# each row don't have the same length, so keep the array type to object
hp = np.array(hp_, dtype=object)
hc = np.array(hc_, dtype=object)
#del hp_, hc_  # free up memory


# compute the noise weighted inner product
hp_inner_hp_list = []
hc_inner_hc_list = []
for det, psd_list in psd_dict.items():
    hp_inner_hp = []
    hc_inner_hc = []
    for i in range(size):  # loop over parameters
        psd_ = np.array(psd_list[i])
        duration_ = duration[i]
        idx2 = (psd_ != 0.0) & (psd_ != np.inf)  # this is necessary to avoid problem in np.sum 
        # it's cumbersome to use jax jitting noise_weighted_inner_product
        # so, I will use numba jitted one instead
        hp_inner_hp.append(self.vmap_noise_weighted_inner_product(
            hp[i][idx2],
            hp[i][idx2],
            psd_[idx2],
            duration_,
        ))

        hc_inner_hc.append(noise_weighted_inner_product(
            hc[i][idx2],
            hc[i][idx2],
            psd_[idx2],
            duration_,
        ))

    hp_inner_hp_list.append(hp_inner_hp)
    hc_inner_hc_list.append(hc_inner_hc)

hp_inner_hp = np.array(hp_inner_hp_list)
hc_inner_hc = np.array(hc_inner_hc_list)

# %%
ans = test.noise_weighted_inner_prod(gw_param_dict, psd_dict, duration=None, verbose=False, duration_min=2, duration_max=64)
# Out:
# setup time:  0.10905790328979492
# duration calculation time:  0.05954384803771973
# setup time:  1.8899898529052734
# waveform generation time:  1.2709009647369385
# psd generation time:  10.304682970046997
# setup time:  24.447003841400146
# inner product time:  29.904842853546143
# setup time:  0.0164792537689209

# %% [markdown]
# * convert inner product to vmap
# * psd generation time and setup time to multiprocessing

# %%
def _helper(hp,hc,fsize_arr,fs):
    # set up h+,hx for inner_product
    hp_, hc_ = [], []
    for i in range(size):
        # remove the np.nan padding
        hp_.append(np.array(hp[i][:fsize_arr[i]], dtype=np.complex128))
        hc_.append(np.array(hc[i][:fsize_arr[i]], dtype=np.complex128))
        # find the index of 20Hz or nearby
        # set all elements to zero below this index
        idx = np.abs(fs[i] - self.f_l).argmin()
        hp_[i][0:idx] = 0.0 + 0.0j
        hc_[i][0:idx] = 0.0 + 0.0j
    # each row don't have the same length, so keep the array type to object
    hp = np.array(hp_, dtype=object)
    hc = np.array(hc_, dtype=object)

    return hp,hc

# %%
hp_inner_hp, hc_inner_hc, fs, psd_dict, fsize_arr, del_f  = test.noise_weighted_inner_prod(gw_param_dict, psd_dict, duration=None, verbose=False, duration_min=2, duration_max=64)
# Out:
# setup time:  0.10808801651000977
# duration calculation time:  0.06410765647888184
# setup time:  0.7802941799163818
# waveform generation time:  1.5824799537658691
# psd generation time:  2.86651611328125
# setup time:  9.871968984603882
# inner product time:  6.127278089523315
# setup time:  0.007072925567626953

# %%
df = min(del_f)*0.1
flist = np.arange(0.0, 1024 + df, df)
len(flist)
# Out:
# 92161

# %% [markdown]
# * rewrite psd generator from bilby
#   * generate once for the highest array length and pick points
# * write a njit fn for 'set up h+,hx for inner_product': for loop is the problem here
# * write a jax.jit+jax.vmap for inner product

# %%
# %prun hp_inner_hp, hc_inner_hc  = test.noise_weighted_inner_prod(gw_param_dict, psd_dict, duration=None, verbose=False, duration_min=2, duration_max=64)
# Out:
#          24091631 function calls (23984225 primitive calls) in 16.979 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    380702    3.535    0.000    3.535    0.000 {built-in method numpy.array}
#         1    1.935    1.935   16.419   16.419 ripple_class.py:127(noise_weighted_inner_prod)
#    120000    1.426    0.000    1.426    0.000 njit_functions.py:282(noise_weighted_inner_product)
#    119966    1.346    0.000    2.171    0.000 dispatch.py:84(apply_primitive)
#     38325    0.985    0.000    0.985    0.000 {built-in method numpy.core._multiarray_umath.interp}
#        20    0.952    0.048    0.956    0.048 compiler.py:240(backend_compile)
#     80000    0.581    0.000    5.025    0.000 lax_numpy.py:11306(_attempt_rewriting_take_via_slice)
#         1    0.571    0.571   16.991   16.991 <string>:1(<module>)
#   2755882    0.418    0.000    0.503    0.000 config.py:293(value)
# 369647/331322    0.279    0.000    1.530    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     38325    0.238    0.000    1.733    0.000 psd.py:59(_update_cache)
#    120436    0.206    0.000    0.594    0.000 config.py:194(trace_context)
#     38325    0.190    0.000    0.190    0.000 _interpolate.py:774(_check_bounds)
# 2314832/2314800    0.147    0.000    0.150    0.000 {built-in method builtins.isinstance}
# 127194/119988    0.147    0.000    4.675    0.000 core.py:440(bind_with_trace)
#    357968    0.135    0.000    0.135    0.000 {built-in method numpy.asarray}
#     79926    0.134    0.000    1.600    0.000 slicing.py:1322(_slice_impl)
#     80000    0.115    0.000    5.264    0.000 array.py:333(__getitem__)
#   3026400    0.097    0.000    0.097    0.000 {method 'get' of 'dict' objects}
#     20050    0.095    0.000    0.136    0.000 dtypes.py:514(_dtype_and_weaktype)
# 120134/120106    0.091    0.000    0.710    0.000 util.py:298(wrapper)
#    100871    0.082    0.000    0.231    0.000 dtypes.py:688(dtype)
#    359619    0.080    0.000    0.225    0.000 {built-in method builtins.any}
#     38325    0.080    0.000    1.339    0.000 _interpolate.py:759(_evaluate)
#    127194    0.076    0.000    0.245    0.000 core.py:1387(find_top_trace)
#     60000    0.075    0.000    0.107    0.000 numeric.py:2402(array_equal)
# 127093/123577    0.074    0.000    3.525    0.000 core.py:435(bind)
#    151549    0.063    0.000    0.072    0.000 contextlib.py:102(__init__)
# 119986/119975    0.062    0.000    3.732    0.000 core.py:949(process_primitive)
#    210889    0.057    0.000    0.093    0.000 {built-in method builtins.max}
#     20049    0.057    0.000    0.057    0.000 {built-in method numpy.arange}
#    133547    0.056    0.000    0.106    0.000 core.py:533(full_raise)
# 198057/194015    0.054    0.000    0.149    0.000 {built-in method builtins.all}
#     82702    0.053    0.000    0.079    0.000 fromnumeric.py:1965(shape)
# 316092/292022    0.053    0.000    0.197    0.000 {built-in method builtins.next}
#    127231    0.050    0.000    0.088    0.000 core.py:1004(with_cur_sublevel)
#     38325    0.048    0.000    0.098    0.000 _util.py:275(_asarray_validated)
#    160141    0.048    0.000    0.066    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#    200009    0.046    0.000    0.071    0.000 array.py:256(ndim)
# 151549/139553    0.046    0.000    0.130    0.000 contextlib.py:139(__exit__)
# 994717/994701    0.046    0.000    0.046    0.000 {built-in method builtins.len}
#    200000    0.045    0.000    0.069    0.000 lax_numpy.py:11317(<genexpr>)
#    173794    0.043    0.000    0.207    0.000 {jaxlib.utils.safe_map}
#     80000    0.041    0.000    0.303    0.000 lax_numpy.py:11286(_is_valid_integer_index_for_slice)
#    520050    0.041    0.000    0.041    0.000 array.py:248(shape)
#     40207    0.038    0.000    1.079    0.000 lax.py:1771(squeeze)
#     80121    0.037    0.000    2.241    0.000 slicing.py:56(slice)
#     78327    0.036    0.000    0.083    0.000 numerictypes.py:356(issubdtype)
# 151549/139553    0.036    0.000    0.141    0.000 contextlib.py:130(__enter__)
#    151549    0.035    0.000    0.107    0.000 contextlib.py:279(helper)
#     81068    0.034    0.000    0.047    0.000 dtypes.py:344(issubdtype)
#    120000    0.033    0.000    0.045    0.000 lax_numpy.py:11278(_is_integer_index)
#     80000    0.031    0.000    5.056    0.000 lax_numpy.py:11387(_rewriting_take)
#        20    0.030    0.002    0.032    0.002 pxla.py:1268(__call__)
#    199852    0.029    0.000    0.034    0.000 lax_numpy.py:11370(<genexpr>)
#    156654    0.029    0.000    0.044    0.000 numerictypes.py:282(issubclass_)
#    375/20    0.028    0.000    0.338    0.017 mlir.py:1741(jaxpr_subcomp)
#    120000    0.027    0.000    0.038    0.000 lax_numpy.py:11337(<genexpr>)
#      3665    0.026    0.000    0.060    0.000 mlir.py:462(_traceback_to_location)
#     38325    0.026    0.000    1.493    0.000 _polyint.py:59(__call__)
#     82702    0.025    0.000    0.128    0.000 <__array_function__ internals>:177(shape)
#    423894    0.025    0.000    0.025    0.000 {built-in method builtins.hasattr}
#    639727    0.025    0.000    0.025    0.000 {method 'append' of 'list' objects}
#     60000    0.024    0.000    1.893    0.000 psd.py:244(get_power_spectral_density_array)
#     80034    0.024    0.000    0.070    0.000 sharding_impls.py:1601(is_single_device_sharding)
#     20000    0.023    0.000    0.023    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#     80000    0.023    0.000    0.043    0.000 lax_numpy.py:11300(_is_contiguous_slice)
#     80000    0.022    0.000    0.225    0.000 lax_numpy.py:162(_dtype)
#     80000    0.022    0.000    0.325    0.000 lax_numpy.py:11327(<setcomp>)
#     80034    0.022    0.000    0.038    0.000 sharding_impls.py:450(num_devices)
#    254388    0.021    0.000    0.021    0.000 core.py:1284(pop_level)
#    200000    0.021    0.000    0.026    0.000 lax_numpy.py:11310(<genexpr>)
#    185108    0.021    0.000    0.026    0.000 mlir.py:454(_is_user_file)
#    137906    0.021    0.000    0.033    0.000 core.py:1388(<genexpr>)
#    273346    0.020    0.000    0.020    0.000 {built-in method builtins.issubclass}
#     21675    0.020    0.000    0.020    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    127203    0.020    0.000    0.038    0.000 core.py:1377(full_lower)
#    127614    0.019    0.000    0.019    0.000 core.py:528(__init__)
#     38325    0.019    0.000    1.034    0.000 function_base.py:1456(interp)
#     80000    0.018    0.000    0.038    0.000 lax_numpy.py:11326(<setcomp>)
#    127614    0.018    0.000    0.018    0.000 core.py:1125(cur_sublevel)
# 242828/242411    0.018    0.000    0.019    0.000 {built-in method builtins.getattr}
#     63093    0.018    0.000    0.079    0.000 <__array_function__ internals>:177(result_type)
#     80000    0.017    0.000    0.060    0.000 lax_numpy.py:11329(<setcomp>)
#     99918    0.017    0.000    0.017    0.000 {jaxlib.utils.safe_zip}
#     24050    0.017    0.000    0.041    0.000 config.py:903(update_thread_local_jit_state)
#     48316    0.016    0.000    0.029    0.000 dtypes.py:254(canonicalize_dtype)
#     80000    0.016    0.000    0.020    0.000 lax_numpy.py:11281(_is_simple_reverse_slice)
#     48657    0.016    0.000    0.042    0.000 {built-in method builtins.sorted}
#    160266    0.016    0.000    0.016    0.000 array.py:264(sharding)
#     47165    0.014    0.000    0.076    0.000 <__array_function__ internals>:177(ndim)
#     60000    0.014    0.000    0.136    0.000 <__array_function__ internals>:177(array_equal)
#        20    0.014    0.001    0.022    0.001 mlir.py:590(make_ir_context)
#    120000    0.014    0.000    0.020    0.000 core.py:2152(is_symbolic_dim)
#     38325    0.013    0.000    0.115    0.000 _polyint.py:90(_prepare_x)
#    119926    0.013    0.000    0.013    0.000 {method 'indices' of 'slice' objects}
#     79926    0.013    0.000    0.013    0.000 lax_numpy.py:11371(<listcomp>)
#     40835    0.012    0.000    0.015    0.000 util.py:385(canonicalize_axis)
#    160000    0.012    0.000    0.012    0.000 lax_numpy.py:11314(<genexpr>)
#      33/2    0.012    0.000    0.438    0.219 core.py:489(eval_jaxpr)
#     80414    0.012    0.000    0.026    0.000 lax.py:1774(<genexpr>)
#     80034    0.011    0.000    0.011    0.000 sharding_impls.py:454(device_set)
#     79926    0.011    0.000    0.011    0.000 lax_numpy.py:11372(<listcomp>)
#    160000    0.011    0.000    0.011    0.000 lax_numpy.py:11322(<genexpr>)
#     27918    0.011    0.000    0.011    0.000 {built-in method __new__ of type object at 0x104a8b040}
#     80035    0.011    0.000    0.011    0.000 array.py:591(_check_if_deleted)
#     38325    0.010    0.000    1.066    0.000 _interpolate.py:686(_call_linear_np)
#      6167    0.010    0.000    0.017    0.000 _ods_common.py:133(get_op_result_or_op_results)
#     38325    0.010    0.000    1.055    0.000 <__array_function__ internals>:177(interp)
#     47165    0.010    0.000    0.030    0.000 fromnumeric.py:3121(ndim)
# 3665/3373    0.010    0.000    0.184    0.000 mlir.py:1884(lower_per_platform)
#     38325    0.009    0.000    0.029    0.000 <__array_function__ internals>:177(iscomplexobj)
#      7742    0.009    0.000    0.026    0.000 xla_metadata.py:33(set_xla_metadata)
#     40000    0.009    0.000    0.009    0.000 _internal.py:918(npy_ctypes_check)
#      3823    0.009    0.000    0.114    0.000 partial_eval.py:1971(default_process_primitive)
#     22632    0.009    0.000    0.009    0.000 dtypes.py:669(is_weakly_typed)
#    3383/2    0.009    0.000    1.696    0.848 batching.py:476(process_primitive)
#      1435    0.008    0.000    0.011    0.000 _stablehlo_ops_gen.py:708(__init__)
#     20000    0.008    0.000    0.065    0.000 numeric.py:289(full)
#      1574    0.008    0.000    0.011    0.000 _stablehlo_ops_gen.py:3264(__init__)
#     14180    0.008    0.000    0.011    0.000 _ods_common.py:90(get_op_result_or_value)
#     38325    0.008    0.000    0.014    0.000 _polyint.py:96(_finish_y)
#     38325    0.008    0.000    0.010    0.000 type_check.py:303(iscomplexobj)
#    120014    0.008    0.000    0.008    0.000 core.py:946(pure)
#     24068    0.008    0.000    0.025    0.000 __init__.py:430(_replace)
#      3517    0.007    0.000    0.061    0.000 utils.py:49(standard_abstract_eval)
#      7742    0.007    0.000    0.022    0.000 compute_on.py:29(extend_compute_type)
#      7742    0.007    0.000    0.112    0.000 core.py:276(manager)
#      3828    0.006    0.000    0.013    0.000 partial_eval.py:1952(makevar)
#      1236    0.006    0.000    0.007    0.000 _stablehlo_ops_gen.py:1322(__init__)
#     82702    0.006    0.000    0.006    0.000 fromnumeric.py:1961(_shape_dispatcher)
#     38345    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3871    0.006    0.000    0.043    0.000 contextlib.py:533(__exit__)
#      9748    0.005    0.000    0.008    0.000 core.py:1708(canonicalize_shape)
#     24068    0.005    0.000    0.017    0.000 __init__.py:420(_make)
#      8950    0.005    0.000    0.018    0.000 core.py:1760(__init__)
#     20000    0.005    0.000    0.051    0.000 <__array_function__ internals>:177(copyto)
#      3859    0.005    0.000    0.012    0.000 core.py:340(new_jaxpr_eqn)
#      2788    0.005    0.000    0.012    0.000 lax.py:2051(broadcasting_shape_rule)
#     14402    0.005    0.000    0.008    0.000 source_info_util.py:246(user_context)
#      7201    0.004    0.000    0.007    0.000 core.py:3422(clean_up_dead_vars)
#     20000    0.004    0.000    0.118    0.000 <__array_function__ internals>:177(concatenate)
#       383    0.004    0.000    0.026    0.000 partial_eval.py:1846(_inline_literals)
#     38325    0.004    0.000    0.007    0.000 _base.py:1513(issparse)
#      2660    0.004    0.000    0.164    0.000 batching.py:1046(broadcast_batcher)
#      2788    0.004    0.000    0.019    0.000 lax.py:2023(naryop_dtype_rule)
#     11613    0.004    0.000    0.054    0.000 contextlib.py:482(enter_context)
#      2830    0.004    0.000    0.039    0.000 mlir.py:2221(multi_broadcast_in_dim)
#      3665    0.004    0.000    0.073    0.000 mlir.py:503(_source_info_to_location)
#      3826    0.004    0.000    0.004    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.name}
#     38325    0.004    0.000    0.004    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     38325    0.004    0.000    0.006    0.000 core.py:6425(isMaskedArray)
#        20    0.004    0.000    0.004    0.000 mlir.py:584(module_to_bytecode)
#      3383    0.004    0.000    0.019    0.000 batching.py:461(get_frame)
#     10325    0.004    0.000    0.010    0.000 core.py:2178(definitely_equal_shape)
#     21675    0.004    0.000    0.027    0.000 {method 'all' of 'numpy.ndarray' objects}
#     47479    0.004    0.000    0.004    0.000 partial_eval.py:1897(frame)
#     60000    0.004    0.000    0.004    0.000 numeric.py:2398(_array_equal_dispatcher)
#      7742    0.004    0.000    0.021    0.000 config.py:298(__call__)
#      6273    0.004    0.000    0.004    0.000 _ods_common.py:78(get_default_loc_context)
#       383    0.004    0.000    0.012    0.000 partial_eval.py:1793(_const_folding_and_forwarding)
#        20    0.004    0.000    0.007    0.000 cache_key.py:157(_canonicalize_ir)
#      3385    0.004    0.000    0.011    0.000 core.py:1407(<dictcomp>)
#      4579    0.004    0.000    0.006    0.000 util.py:93(unzip2)
#     63093    0.004    0.000    0.004    0.000 multiarray.py:664(result_type)
#     80200    0.004    0.000    0.004    0.000 dtypes.py:516(<genexpr>)
#     21940    0.004    0.000    0.011    0.000 lax.py:2031(<genexpr>)
#     47165    0.003    0.000    0.003    0.000 fromnumeric.py:3117(_ndim_dispatcher)
#     11613    0.003    0.000    0.008    0.000 contextlib.py:509(_push_cm_exit)
#     54120    0.003    0.000    0.003    0.000 {built-in method _operator.index}
#     21675    0.003    0.000    0.023    0.000 _methods.py:60(_all)
#     11323    0.003    0.000    0.005    0.000 source_info_util.py:156(replace)
#        20    0.003    0.000    0.370    0.018 mlir.py:1044(lower_jaxpr_to_module)
#       569    0.003    0.000    0.004    0.000 _stablehlo_ops_gen.py:56(__init__)
#      9651    0.003    0.000    0.005    0.000 core.py:362(__init__)
#     20042    0.003    0.000    0.003    0.000 {built-in method numpy.empty}
#        20    0.003    0.000    0.003    0.000 cache_key.py:148(_serialize_ir)
#      6823    0.003    0.000    0.016    0.000 batching.py:1059(<genexpr>)
#        20    0.003    0.000    0.003    0.000 {built-in method jaxlib.mlir._mlir_libs._mlirHlo.register_mhlo_dialect}
#     12927    0.003    0.000    0.005    0.000 core.py:1409(definitely_equal)
#      1435    0.003    0.000    0.031    0.000 mlir.py:2192(broadcast_in_dim)
#    101/20    0.003    0.000    0.003    0.000 compiler.py:75(_walk_operations)
#      2792    0.003    0.000    0.072    0.000 lax.py:2205(_nary_lower_hlo)
#     38325    0.003    0.000    0.003    0.000 function_base.py:1452(_interp_dispatcher)
#      7201    0.003    0.000    0.004    0.000 source_info_util.py:125(__add__)
#     19361    0.003    0.000    0.006    0.000 core.py:681(<lambda>)
#      8247    0.003    0.000    0.004    0.000 core.py:318(replace)
#      3830    0.003    0.000    0.004    0.000 partial_eval.py:1606(full_lower)
#      6876    0.003    0.000    0.004    0.000 partial_eval.py:1946(getvar)
#      3705    0.003    0.000    0.004    0.000 source_info_util.py:131(__str__)
#      8950    0.003    0.000    0.003    0.000 core.py:1619(_dtype_object)
#      3123    0.003    0.000    0.003    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.callsite}
#     38325    0.002    0.000    0.002    0.000 type_check.py:206(_is_type_dispatcher)
#       383    0.002    0.000    0.043    0.000 partial_eval.py:1733(to_jaxpr)
#     20079    0.002    0.000    0.138    0.000 dtypes.py:713(<genexpr>)
#     10950    0.002    0.000    0.003    0.000 core.py:180(jaxprs_in_params)
#        20    0.002    0.000    0.002    0.000 {built-in method jaxlib.mlir._mlir_libs._stablehlo.register_dialect}
#       120    0.002    0.000    0.002    0.000 {method 'update' of '_hashlib.HASH' objects}
#     12106    0.002    0.000    0.002    0.000 core.py:305(__init__)
#      3484    0.002    0.000    0.004    0.000 core.py:2706(subst_axis_names)
#      9396    0.002    0.000    0.003    0.000 partial_eval.py:1858(lit)
#     38/20    0.002    0.000    0.008    0.000 partial_eval.py:1472(_dce_jaxpr)
#     38325    0.002    0.000    0.002    0.000 psd.py:254(power_spectral_density_interpolated)
#      5355    0.002    0.000    0.006    0.000 partial_eval.py:1769(newvar)
#     11613    0.002    0.000    0.003    0.000 contextlib.py:514(_push_exit_callback)
#       383    0.002    0.000    0.003    0.000 partial_eval.py:1872(<setcomp>)
#       408    0.002    0.000    0.003    0.000 core.py:3412(last_used)
#     10260    0.002    0.000    0.007    0.000 partial_eval.py:1864(<lambda>)
#        29    0.002    0.000    0.140    0.005 dtypes.py:712(_lattice_result_type)
#      7440    0.002    0.000    0.003    0.000 mlir.py:852(flatten_ir_values)
#      7021    0.002    0.000    0.023    0.000 mlir.py:1756(read)
#      7201    0.002    0.000    0.003    0.000 core.py:3425(<setcomp>)
#   383/355    0.002    0.000    0.499    0.001 partial_eval.py:2284(trace_to_subjaxpr_dynamic)
#      5357    0.002    0.000    0.003    0.000 partial_eval.py:1599(__init__)
#      8393    0.002    0.000    0.003    0.000 batching.py:463(<genexpr>)
#     10742    0.002    0.000    0.005    0.000 core.py:2124(raise_to_shaped)
#       493    0.002    0.000    0.003    0.000 dataclasses.py:1405(replace)
#      3117    0.002    0.000    0.004    0.000 mlir.py:195(dtype_to_ir_type)
#      1066    0.002    0.000    0.004    0.000 partial_eval.py:1919(_new_const)
#      7742    0.002    0.000    0.015    0.000 config.py:1142(<lambda>)
#      1116    0.002    0.000    0.007    0.000 core.py:1853(__init__)
#     20121    0.002    0.000    0.004    0.000 tree_util.py:344(<genexpr>)
#      3385    0.002    0.000    0.012    0.000 core.py:1406(dedup_referents)
#      3822    0.002    0.000    0.005    0.000 partial_eval.py:1883(<listcomp>)
#      1881    0.002    0.000    0.009    0.000 mlir.py:209(_array_ir_types)
#      9964    0.002    0.000    0.002    0.000 source_info_util.py:226(current)
#      3484    0.002    0.000    0.006    0.000 core.py:2701(used_axis_names)
#     37/20    0.002    0.000    0.344    0.017 mlir.py:1315(lower_jaxpr_to_fun)
#       319    0.002    0.000    0.002    0.000 _stablehlo_ops_gen.py:5039(__init__)
#      3824    0.002    0.000    0.002    0.000 core.py:265(__init__)
#      1271    0.002    0.000    0.020    0.000 partial_eval.py:1908(new_const)
#      1187    0.002    0.000    0.002    0.000 partial_eval.py:1669(make_jaxpr_effects)
#      7805    0.002    0.000    0.002    0.000 core.py:1689(_canonicalize_dimension)
#      3784    0.002    0.000    0.067    0.000 core.py:474(abstract_eval_)
#         1    0.002    0.002    0.059    0.059 __init__.py:40(ms_to_Mc_eta)
#        32    0.002    0.000    0.002    0.000 tree_util.py:88(tree_leaves)
#      4671    0.002    0.000    0.003    0.000 batching.py:377(__init__)
#      3420    0.001    0.000    0.002    0.000 batching.py:431(__init__)
#     10304    0.001    0.000    0.003    0.000 mlir.py:1841(<genexpr>)
#     20614    0.001    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#      1236    0.001    0.000    0.018    0.000 mlir.py:277(_numpy_array_constant)
#      3825    0.001    0.000    0.117    0.000 partial_eval.py:1966(process_primitive)
#     10309    0.001    0.000    0.006    0.000 mlir.py:1763(aval)
#     11136    0.001    0.000    0.001    0.000 core.py:1046(__eq__)
#     20063    0.001    0.000    0.005    0.000 lax_numpy.py:5406(<genexpr>)
#      3668    0.001    0.000    0.002    0.000 mlir.py:1960(<lambda>)
#     22966    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#      8317    0.001    0.000    0.002    0.000 mlir.py:149(_is_ir_values)
#     11613    0.001    0.000    0.001    0.000 contextlib.py:442(_create_exit_wrapper)
#      3414    0.001    0.000    0.002    0.000 utils.py:97(_standard_weak_type_rule)
#      3665    0.001    0.000    0.003    0.000 mlir.py:1301(subset)
#      3826    0.001    0.000    0.002    0.000 mlir.py:1280(__init__)
#       239    0.001    0.000    0.002    0.000 _stablehlo_ops_gen.py:1855(__init__)
#      9847    0.001    0.000    0.001    0.000 partial_eval.py:1656(_assert_live)
#      9967    0.001    0.000    0.002    0.000 utils.py:51(<genexpr>)
#      3825    0.001    0.000    0.003    0.000 partial_eval.py:1802(<listcomp>)
#     11323    0.001    0.000    0.001    0.000 source_info_util.py:152(__init__)
#     20614    0.001    0.000    0.003    0.000 abc.py:117(__instancecheck__)
#      9616    0.001    0.000    0.001    0.000 batching.py:479(<genexpr>)
#      3670    0.001    0.000    0.002    0.000 mlir.py:1964(<lambda>)
#      5016    0.001    0.000    0.002    0.000 util.py:586(__init__)
#      9485    0.001    0.000    0.002    0.000 core.py:2173(<genexpr>)
#      1975    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.get}
#      4250    0.001    0.000    0.004    0.000 partial_eval.py:1863(<lambda>)
#      3823    0.001    0.000    0.003    0.000 partial_eval.py:1979(<listcomp>)
#       174    0.001    0.000    0.002    0.000 _stablehlo_ops_gen.py:4876(__init__)
#     20039    0.001    0.000    0.002    0.000 lax_numpy.py:5378(<lambda>)
#       213    0.001    0.000    0.004    0.000 core.py:190(subjaxprs)
#      5320    0.001    0.000    0.002    0.000 batching.py:1057(<genexpr>)
#     10712    0.001    0.000    0.001    0.000 core.py:1384(_get_trace_level)
#      3825    0.001    0.000    0.001    0.000 partial_eval.py:1730(add_eqn)
#      7267    0.001    0.000    0.002    0.000 partial_eval.py:1798(apply_var_sub)
#     20000    0.001    0.000    0.001    0.000 multiarray.py:148(concatenate)
#      1435    0.001    0.000    0.016    0.000 _stablehlo_ops_gen.py:737(broadcast_in_dim)
#       430    0.001    0.000    0.002    0.000 lax.py:4430(_compute_squeeze_shape)
#       378    0.001    0.000    0.059    0.000 lax.py:527(_convert_element_type)
#      8638    0.001    0.000    0.002    0.000 core.py:1400(get_referent)
#       335    0.001    0.000    0.054    0.000 mlir.py:2042(f_lowered)
#      4110    0.001    0.000    0.001    0.000 mlir.py:1769(write)
#      3640    0.001    0.000    0.002    0.000 core.py:493(write)
#     20000    0.001    0.000    0.001    0.000 multiarray.py:1071(copyto)
#      1574    0.001    0.000    0.016    0.000 _stablehlo_ops_gen.py:3287(multiply)
#        20    0.001    0.000    0.001    0.000 __init__.py:126(__init__)
#      6510    0.001    0.000    0.001    0.000 core.py:490(read)
#      8234    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#      7330    0.001    0.000    0.001    0.000 mlir.py:1874(_platforms_for_eqn_ctx)
#      7756    0.001    0.000    0.001    0.000 source_info_util.py:89(wrap)
#      3687    0.001    0.000    0.001    0.000 effects.py:100(filter_in)
#      1236    0.001    0.000    0.019    0.000 mlir.py:293(_ndarray_constant_handler)
#        20    0.001    0.000    0.372    0.019 pxla.py:1887(_cached_lowering_to_hlo)
#        56    0.001    0.000    0.006    0.000 tree_util.py:336(tree_map)
#       188    0.001    0.000    0.001    0.000 _stablehlo_ops_gen.py:4112(__init__)
#       801    0.001    0.000    0.004    0.000 lax.py:5981(_check_shapelike)
#      1192    0.001    0.000    0.004    0.000 xla.py:172(_make_shaped_array_for_numpy_array)
#     15597    0.001    0.000    0.001    0.000 typing.py:1737(cast)
#      5136    0.001    0.000    0.001    0.000 mlir.py:2166(wrap_compute_type_in_place)
#      9333    0.001    0.000    0.001    0.000 partial_eval.py:1478(read)
#      1116    0.001    0.000    0.009    0.000 abstract_arrays.py:49(canonical_concrete_aval)
#        20    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._chlo.register_dialect}
#      6741    0.001    0.000    0.002    0.000 partial_eval.py:1481(write)
#       205    0.001    0.000    0.012    0.000 lax.py:4446(_squeeze_batch_rule)
#      6564    0.001    0.000    0.001    0.000 core.py:1780(<lambda>)
#      4082    0.001    0.000    0.004    0.000 core.py:2171(is_constant_shape)
#      5459    0.001    0.000    0.001    0.000 core.py:2160(is_constant_dim)
#      1236    0.001    0.000    0.012    0.000 _stablehlo_ops_gen.py:1349(constant)
#     16388    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      3824    0.001    0.000    0.001    0.000 compute_on.py:45(current_compute_type)
#       159    0.001    0.000    0.001    0.000 _stablehlo_ops_gen.py:3570(__init__)
#    465/80    0.001    0.000    1.852    0.023 profiler.py:330(wrapper)
#       824    0.001    0.000    0.003    0.000 core.py:1220(new_main)
#      2727    0.001    0.000    0.001    0.000 lax.py:2055(<setcomp>)
#        20    0.001    0.000    0.391    0.020 pxla.py:2140(lower_sharding_computation)
#     37/20    0.001    0.000    0.003    0.000 dispatch.py:227(get_intermediate_shardings)
#      3823    0.001    0.000    0.001    0.000 partial_eval.py:1972(<listcomp>)
#       461    0.001    0.000    0.002    0.000 partial_eval.py:1901(new_arg)
#      4910    0.001    0.000    0.002    0.000 lax.py:2061(<genexpr>)
#      3670    0.001    0.000    0.001    0.000 mlir.py:2173(wrap_xla_metadata_in_place)
# 1238/1236    0.001    0.000    0.020    0.000 mlir.py:258(ir_constant)
#        20    0.001    0.000    0.002    0.000 pxla.py:2053(get_out_layouts_via_propagation)
#       159    0.001    0.000    0.053    0.000 lax.py:2580(_pow_lower)
#      2791    0.001    0.000    0.002    0.000 utils.py:31(_input_dtype)
#       122    0.001    0.000    0.001    0.000 tree_util.py:74(tree_flatten)
#    166/74    0.001    0.000    0.002    0.000 partial_eval.py:1398(_jaxpr_forwarding)
#    385/22    0.001    0.000    1.699    0.077 linear_util.py:179(call_wrapped)
#        20    0.001    0.000    0.976    0.049 pxla.py:2800(from_hlo)
#      3822    0.001    0.000    0.005    0.000 partial_eval.py:1884(<listcomp>)
#      7412    0.001    0.000    0.001    0.000 batching.py:486(<genexpr>)
#     20071    0.001    0.000    0.001    0.000 lax_numpy.py:5381(<genexpr>)
#      8379    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#      1116    0.001    0.000    0.010    0.000 core.py:1522(concrete_aval)
#       192    0.001    0.000    0.003    0.000 lax.py:3956(_broadcast_in_dim_shape_rule)
#     11613    0.001    0.000    0.001    0.000 {method 'pop' of 'collections.deque' objects}
#      3871    0.001    0.000    0.001    0.000 contextlib.py:452(__init__)
#      2069    0.001    0.000    0.001    0.000 core.py:1605(physical_aval)
#     11613    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#      3665    0.001    0.000    0.001    0.000 mlir.py:1786(get_override_lowering_rule)
#      6454    0.001    0.000    0.001    0.000 utils.py:47(_get_array_abstraction_level)
#      1272    0.001    0.000    0.001    0.000 core.py:121(__init__)
#      3254    0.001    0.000    0.001    0.000 mlir.py:2213(<genexpr>)
#      3478    0.001    0.000    0.001    0.000 core.py:2717(<listcomp>)
#      3670    0.001    0.000    0.001    0.000 mlir.py:92(_is_not_block_argument)
#      3484    0.001    0.000    0.001    0.000 core.py:2695(__init__)
#   383/355    0.001    0.000    0.503    0.001 partial_eval.py:2267(trace_to_jaxpr_dynamic)
#        20    0.001    0.000    0.010    0.000 cache_key.py:167(_hash_computation)
#       208    0.001    0.000    0.003    0.000 slicing.py:1234(_slice_shape_rule)
#      1811    0.001    0.000    0.001    0.000 core.py:1403(same_referent)
#      4321    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#      7412    0.001    0.000    0.001    0.000 batching.py:462(<genexpr>)
#      2788    0.001    0.000    0.001    0.000 lax.py:2052(<listcomp>)
#      1197    0.001    0.000    0.002    0.000 xla.py:132(_canonicalize_ndarray_dtype)
#      3383    0.001    0.000    0.001    0.000 batching.py:445(get_primitive_batcher)
#     15677    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#      5016    0.001    0.000    0.001    0.000 util.py:590(__hash__)
#      6835    0.001    0.000    0.001    0.000 utils.py:98(<genexpr>)
#        53    0.001    0.000    0.001    0.000 _func_ops_gen.py:136(__init__)
#        21    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      3576    0.001    0.000    0.001    0.000 {built-in method builtins.delattr}
#      3824    0.001    0.000    0.001    0.000 xla_metadata.py:30(current_xla_metadata)
#     20044    0.001    0.000    0.001    0.000 lax_numpy.py:5380(<lambda>)
#      1128    0.001    0.000    0.001    0.000 batching.py:436(pure)
#      7264    0.001    0.000    0.001    0.000 partial_eval.py:1867(vars_in_shape)
#      8426    0.001    0.000    0.001    0.000 core.py:780(_assert_live)
#      3665    0.001    0.000    0.001    0.000 mlir.py:1944(<listcomp>)
#        53    0.001    0.000    0.001    0.000 func.py:95(add_entry_block)
#     33/19    0.001    0.000    0.028    0.001 pjit.py:1913(_pjit_lowering)
#        53    0.001    0.000    0.001    0.000 func.py:77(type)
#      3536    0.000    0.000    0.000    0.000 source_info_util.py:272(current_name_stack)
#        41    0.000    0.000    0.001    0.000 mlir.py:2368(compare_hlo)
#        20    0.000    0.000    1.402    0.070 pjit.py:1709(_pjit_call_impl)
#       383    0.000    0.000    0.002    0.000 partial_eval.py:1855(<dictcomp>)
#     32/20    0.000    0.000    0.327    0.016 lax_numpy.py:5257(array)
# 1450/1444    0.000    0.000    0.010    0.000 core.py:1532(get_aval)
#      3385    0.000    0.000    0.000    0.000 batching.py:408(full_lower)
#      1273    0.000    0.000    0.003    0.000 xla.py:116(canonicalize_dtype)
#       436    0.000    0.000    0.001    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#      1881    0.000    0.000    0.009    0.000 mlir.py:222(aval_to_ir_type)
#      2139    0.000    0.000    0.000    0.000 lax.py:6003(<genexpr>)
#      1061    0.000    0.000    0.001    0.000 core.py:396(__init__)
#      3871    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#      3665    0.000    0.000    0.000    0.000 core.py:432(__repr__)
#        20    0.000    0.000    0.001    0.000 compiler.py:111(get_compile_options)
#       136    0.000    0.000    0.013    0.000 lax.py:1779(expand_dims)
#      4294    0.000    0.000    0.001    0.000 partial_eval.py:2583(_substitute_vars_in_type)
#       939    0.000    0.000    0.001    0.000 lax.py:2066(<listcomp>)
#       569    0.000    0.000    0.006    0.000 _stablehlo_ops_gen.py:79(add)
#      3602    0.000    0.000    0.001    0.000 partial_eval.py:1521(_default_dce_rule)
#      3373    0.000    0.000    0.000    0.000 dispatch.py:308(_eqn_replicas)
#      3871    0.000    0.000    0.000    0.000 xla_metadata.py:52(<genexpr>)
#      3871    0.000    0.000    0.000    0.000 xla_metadata.py:45(<genexpr>)
#      1229    0.000    0.000    0.005    0.000 xla.py:150(abstractify)
#      2318    0.000    0.000    0.000    0.000 dtypes.py:683(check_valid_dtype)
#      1187    0.000    0.000    0.000    0.000 partial_eval.py:1672(<dictcomp>)
#        18    0.000    0.000    0.008    0.000 pjit.py:539(_infer_params_impl)
#      3798    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._sdy.register_dialect}
#      1631    0.000    0.000    0.000    0.000 util.py:592(__eq__)
#      3687    0.000    0.000    0.000    0.000 effects.py:101(<listcomp>)
#       766    0.000    0.000    0.002    0.000 source_info_util.py:296(reset_name_stack)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1716(__init__)
#      3536    0.000    0.000    0.000    0.000 core.py:469(get_bind_params)
#        53    0.000    0.000    0.001    0.000 _func_ops_gen.py:249(__init__)
#      1076    0.000    0.000    0.003    0.000 core.py:2139(<lambda>)
#       331    0.000    0.000    0.001    0.000 core.py:826(__getattr__)
#      3905    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#      3871    0.000    0.000    0.000    0.000 compute_on.py:35(<lambda>)
#       766    0.000    0.000    0.002    0.000 core.py:1076(_update_thread_local_jit_state)
#        51    0.000    0.000    0.000    0.000 _func_ops_gen.py:64(__init__)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1875(<setcomp>)
#       385    0.000    0.000    0.001    0.000 linear_util.py:264(wrap_init)
#    166/74    0.000    0.000    0.003    0.000 pjit.py:1831(_pjit_forwarding)
#      4344    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#      1776    0.000    0.000    0.001    0.000 lax.py:2069(<genexpr>)
#        20    0.000    0.000    0.969    0.048 compiler.py:297(compile_or_get_cached)
#       766    0.000    0.000    0.000    0.000 source_info_util.py:286(set_name_stack)
#       335    0.000    0.000    0.000    0.000 mlir.py:2028(_ir_consts)
#       218    0.000    0.000    0.001    0.000 ipkernel.py:790(<setcomp>)
#       194    0.000    0.000    0.030    0.000 lax.py:1158(broadcast_in_dim)
#        16    0.000    0.000    0.009    0.001 mlir.py:1703(_emit_lowering_rule_as_fun)
#        22    0.000    0.000    0.009    0.000 pjit.py:713(_infer_params)
#       383    0.000    0.000    0.003    0.000 partial_eval.py:2563(_input_type_to_tracers)
#       174    0.000    0.000    0.004    0.000 mlir.py:2249(slice_op)
#      1819    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.get_dynamic_size}
#       434    0.000    0.000    0.001    0.000 core.py:1769(update)
#      3665    0.000    0.000    0.000    0.000 mlir.py:1303(<genexpr>)
#       192    0.000    0.000    0.004    0.000 lax.py:4153(_broadcast_in_dim_abstract_eval)
#        41    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1094(__init__)
#       493    0.000    0.000    0.003    0.000 mlir.py:807(replace)
#        20    0.000    0.000    0.012    0.001 cache_key.py:64(get)
#       218    0.000    0.000    0.000    0.000 threading.py:1478(enumerate)
#       319    0.000    0.000    0.003    0.000 _stablehlo_ops_gen.py:5062(subtract)
#      3873    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#      3871    0.000    0.000    0.000    0.000 contextlib.py:530(__enter__)
#       378    0.000    0.000    0.000    0.000 typing.py:1247(__hash__)
#        20    0.000    0.000    0.022    0.001 mlir.py:714(__init__)
#        42    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4582(__init__)
#       193    0.000    0.000    0.009    0.000 slicing.py:1291(_slice_batching_rule)
#        51    0.000    0.000    0.000    0.000 func.py:85(name)
#        20    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#      3416    0.000    0.000    0.000    0.000 pxla.py:2066(write)
#       203    0.000    0.000    0.000    0.000 util.py:125(split_list)
#        20    0.000    0.000    0.000    0.000 copy.py:259(_reconstruct)
#       188    0.000    0.000    0.003    0.000 mlir.py:2239(reshape)
#        42    0.000    0.000    0.001    0.000 pjit.py:242(_get_fastpath_data)
#       260    0.000    0.000    0.008    0.000 batching.py:1075(_handle_scalar_broadcasting)
#       766    0.000    0.000    0.000    0.000 partial_eval.py:2337(extend_jaxpr_stack)
#       516    0.000    0.000    0.000    0.000 lax.py:4076(_broadcast_in_dim_fwd_rule)
#      37/2    0.000    0.000    1.695    0.848 pjit.py:1941(_pjit_batcher)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1853(<listcomp>)
#     37/20    0.000    0.000    0.002    0.000 pxla.py:1988(jaxpr_transfer_mem_kinds)
#    103/68    0.000    0.000    0.000    0.000 functools.py:961(__get__)
#       186    0.000    0.000    0.001    0.000 lax.py:1992(unop_dtype_rule)
#      3825    0.000    0.000    0.000    0.000 partial_eval.py:1804(<genexpr>)
#      1526    0.000    0.000    0.000    0.000 threading.py:1145(ident)
#       166    0.000    0.000    0.001    0.000 partial_eval.py:1428(prune_closed_jaxpr_outputs)
#        18    0.000    0.000    0.001    0.000 array.py:1133(_array_shard_arg)
#        41    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3296(__init__)
#       334    0.000    0.000    0.008    0.000 mlir.py:2043(<lambda>)
#       316    0.000    0.000    0.000    0.000 core.py:213(in_avals)
#       239    0.000    0.000    0.003    0.000 _stablehlo_ops_gen.py:1878(divide)
#      3016    0.000    0.000    0.000    0.000 core.py:105(outvars)
#    128/82    0.000    0.000    0.002    0.000 pjit.py:1841(pjit_forwarding_rule)
#       860    0.000    0.000    0.000    0.000 lax.py:4436(<genexpr>)
#     37/20    0.000    0.000    0.002    0.000 dispatch.py:211(jaxpr_has_prim_requiring_devices)
#        35    0.000    0.000    0.000    0.000 function_base.py:4999(delete)
#      1236    0.000    0.000    0.000    0.000 {built-in method numpy.ascontiguousarray}
#       207    0.000    0.000    0.000    0.000 batching.py:1138(move_stacked_axis)
#       174    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:4932(slice)
#      2988    0.000    0.000    0.000    0.000 core.py:101(invars)
#       378    0.000    0.000    0.000    0.000 typing.py:306(inner)
#       860    0.000    0.000    0.000    0.000 lax.py:4434(<genexpr>)
#        20    0.000    0.000    0.000    0.000 pxla.py:2551(_get_layouts_from_executable)
#        20    0.000    0.000    0.973    0.049 pxla.py:2642(_cached_compilation)
#        12    0.000    0.000    0.000    0.000 slicing.py:2029(_gather_lower)
#        53    0.000    0.000    0.000    0.000 func.py:69(is_external)
#       188    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:4127(reshape)
#      2687    0.000    0.000    0.000    0.000 core.py:97(constvars)
#       384    0.000    0.000    0.000    0.000 core.py:229(effects)
#        20    0.000    0.000    0.001    0.000 cache_key.py:198(_hash_serialized_compile_options)
#       127    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.file}
#      2519    0.000    0.000    0.000    0.000 core.py:109(eqns)
#     33/19    0.000    0.000    0.027    0.001 pjit.py:1882(_pjit_cached_lower_jaxpr_to_fun)
#       179    0.000    0.000    0.006    0.000 batching.py:1039(vectorized_batcher)
#      1066    0.000    0.000    0.000    0.000 partial_eval.py:1938(_lift_tracers_in_aval)
#      1189    0.000    0.000    0.000    0.000 sharding_impls.py:977(is_unspecified)
#       442    0.000    0.000    0.000    0.000 core.py:1796(__hash__)
#       205    0.000    0.000    0.000    0.000 batching.py:185(shape_as_bdim)
#       811    0.000    0.000    0.000    0.000 mlir.py:1796(<genexpr>)
#       378    0.000    0.000    0.001    0.000 typing.py:1040(__or__)
#         3    0.000    0.000    0.019    0.006 ufuncs.py:2394(power)
#        63    0.000    0.000    0.000    0.000 core.py:163(replace)
#       182    0.000    0.000    0.004    0.000 lax.py:4142(_broadcast_in_dim_lower)
#        40    0.000    0.000    0.000    0.000 function_base.py:2399(_vectorize_call)
#    101/20    0.000    0.000    1.871    0.094 core.py:2797(bind)
#        24    0.000    0.000    0.000    0.000 inspect.py:2280(_signature_from_function)
#       225    0.000    0.000    0.001    0.000 lax.py:4427(_squeeze_shape_rule)
#       159    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:3593(power)
#     80/20    0.000    0.000    0.001    0.000 copy.py:128(deepcopy)
#         7    0.000    0.000    0.000    0.000 pxla.py:214(batched_device_put)
#        22    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1358(__init__)
#       696    0.000    0.000    0.001    0.000 mlir.py:2262(<genexpr>)
#        20    0.000    0.000    0.001    0.000 pxla.py:111(shard_args)
#       766    0.000    0.000    0.000    0.000 core.py:376(gensym)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1878(<listcomp>)
#       408    0.000    0.000    0.000    0.000 core.py:3414(<dictcomp>)
#         9    0.000    0.000    0.036    0.004 ufunc_api.py:170(__call__)
#       855    0.000    0.000    0.000    0.000 lax.py:4440(<genexpr>)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1742(<listcomp>)
#       174    0.000    0.000    0.004    0.000 slicing.py:1333(_slice_lower)
#       255    0.000    0.000    0.000    0.000 core.py:217(out_avals)
#        42    0.000    0.000    0.000    0.000 sharding_impls.py:951(get_replicated)
#       116    0.000    0.000    0.000    0.000 dispatch.py:171(log_elapsed_time)
#       136    0.000    0.000    0.000    0.000 layout.py:47(from_pjrt_layout)
#       510    0.000    0.000    0.000    0.000 linear_util.py:156(__init__)
#       162    0.000    0.000    0.000    0.000 lax.py:2543(_pow_dtype_rule)
#       192    0.000    0.000    0.007    0.000 lax.py:4083(_broadcast_in_dim_staging_rule)
#       493    0.000    0.000    0.000    0.000 dataclasses.py:1205(_is_dataclass_instance)
#      1562    0.000    0.000    0.000    0.000 source_info_util.py:95(wrap)
#       702    0.000    0.000    0.000    0.000 lax.py:2002(<genexpr>)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1886(<listcomp>)
#       130    0.000    0.000    0.001    0.000 batching.py:1068(<listcomp>)
#     38/20    0.000    0.000    0.008    0.000 partial_eval.py:1441(dce_jaxpr)
#        20    0.000    0.000    0.000    0.000 cache_key.py:180(_hash_accelerator_config)
#        20    0.000    0.000    1.401    0.070 pjit.py:1611(_pjit_call_impl_python)
#        17    0.000    0.000    0.009    0.001 mlir.py:2516(cached_lowering)
#        96    0.000    0.000    0.009    0.000 lax.py:2628(_integer_pow_lowering)
#        53    0.000    0.000    0.001    0.000 func.py:38(__init__)
#       757    0.000    0.000    0.000    0.000 mlir.py:1871(<genexpr>)
#       470    0.000    0.000    0.000    0.000 partial_eval.py:1403(<listcomp>)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1877(<listcomp>)
#     22/20    0.000    0.000    1.880    0.094 pjit.py:177(_python_pjit_helper)
#       361    0.000    0.000    0.000    0.000 lax.py:3973(<genexpr>)
#     35/19    0.000    0.000    0.001    0.000 pjit.py:2326(dce_jaxpr_pjit_rule)
#       412    0.000    0.000    0.000    0.000 core.py:987(__init__)
#       436    0.000    0.000    0.000    0.000 __init__.py:96(_xla_gc_callback)
#      37/2    0.000    0.000    0.468    0.234 batching.py:815(batch_jaxpr2)
#       127    0.000    0.000    0.000    0.000 source_info_util.py:181(raw_frame_to_frame)
#        24    0.000    0.000    0.001    0.000 inspect.py:2375(_signature_from_callable)
#        14    0.000    0.000    0.000    0.000 slicing.py:1633(_gather_shape_rule)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:2387(get_states)
#        18    0.000    0.000    0.006    0.000 pjit.py:1265(_create_pjit_jaxpr)
#        20    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3103(__init__)
#        20    0.000    0.000    0.004    0.000 pxla.py:2595(create_compile_options)
#       412    0.000    0.000    0.000    0.000 core.py:1017(next_level)
#        18    0.000    0.000    0.000    0.000 inspect.py:3050(_bind)
#       554    0.000    0.000    0.000    0.000 lax.py:4155(<genexpr>)
#       504    0.000    0.000    0.000    0.000 core.py:2176(<genexpr>)
#        26    0.000    0.000    0.002    0.000 lax.py:4677(_select_batch_rule)
#       106    0.000    0.000    0.000    0.000 func.py:73(body)
#      1486    0.000    0.000    0.000    0.000 core.py:204(<lambda>)
#       345    0.000    0.000    0.000    0.000 sharding_impls.py:980(is_unspecified_or_auto)
#       412    0.000    0.000    0.000    0.000 core.py:1023(pop)
#       138    0.000    0.000    0.000    0.000 pxla.py:1845(__hash__)
#        12    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:2739(__init__)
#        20    0.000    0.000    0.009    0.000 pxla.py:1769(_dce_jaxpr)
#        38    0.000    0.000    0.002    0.000 pjit.py:1777(pjit_staging_rule)
#        20    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.passmanager.parse}
#        20    0.000    0.000    0.000    0.000 pjit.py:1506(_resolve_in_shardings)
#       383    0.000    0.000    0.001    0.000 partial_eval.py:1880(<listcomp>)
#       310    0.000    0.000    0.002    0.000 batching.py:1189(bdim_at_front)
#        18    0.000    0.000    0.001    0.000 api_util.py:671(_arg_names)
#        20    0.000    0.000    0.001    0.000 pxla.py:2672(_maybe_get_and_check_in_shardings)
#       318    0.000    0.000    0.005    0.000 lax.py:509(convert_element_type)
#        12    0.000    0.000    0.001    0.000 slicing.py:1886(_gather_batching_rule)
#        20    0.000    0.000    0.009    0.000 partial_eval.py:1461(dce_jaxpr_consts)
#        20    0.000    0.000    1.401    0.070 pjit.py:1713(call_impl_cache_miss)
#        20    0.000    0.000    0.000    0.000 pjit.py:1446(_resolve_in_layouts)
#      1156    0.000    0.000    0.000    0.000 core.py:117(debug_info)
#        40    0.000    0.000    0.000    0.000 function_base.py:2268(__init__)
#        14    0.000    0.000    0.000    0.000 slicing.py:1794(_gather_shape_computation)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:1826(<listcomp>)
#       412    0.000    0.000    0.000    0.000 core.py:1020(push)
#        20    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.create}
#        59    0.000    0.000    0.000    0.000 source_info_util.py:105(extend)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:2383(set_states)
#      19/2    0.000    0.000    0.468    0.234 batching.py:831(_batch_jaxpr2)
#       136    0.000    0.000    0.000    0.000 layout.py:40(__init__)
#        66    0.000    0.000    0.000    0.000 array.py:537(layout)
#        80    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#       188    0.000    0.000    0.004    0.000 lax.py:4464(_squeeze_lower)
#        59    0.000    0.000    0.000    0.000 sharding_impls.py:890(__eq__)
#       461    0.000    0.000    0.000    0.000 partial_eval.py:2573(_substitute_tracers_in_aval)
#        40    0.000    0.000    0.000    0.000 {built-in method numpy.frompyfunc}
#        20    0.000    0.000    0.391    0.020 pjit.py:1746(_pjit_lower)
#        18    0.000    0.000    0.006    0.000 linear_util.py:338(memoized_fun)
#        22    0.000    0.000    0.000    0.000 array.py:1177(_array_global_result_handler)
#       169    0.000    0.000    0.000    0.000 core.py:2175(definitely_equal_one_of_dim)
#       158    0.000    0.000    0.000    0.000 mlir.py:862(flatten_ir_types)
#       383    0.000    0.000    0.000    0.000 partial_eval.py:2300(<listcomp>)
#        22    0.000    0.000    0.000    0.000 partial_eval.py:908(convert_constvars_jaxpr)
#       130    0.000    0.000    0.008    0.000 batching.py:1071(<listcomp>)
#        20    0.000    0.000    0.000    0.000 mlir.py:1197(_set_up_aliases)
#        20    0.000    0.000    0.000    0.000 compiler.py:704(_cache_write)
#        20    0.000    0.000    0.000    0.000 pxla.py:2418(_get_in_shardings_from_xla)
#       164    0.000    0.000    0.000    0.000 util.py:188(concatenate)
#       118    0.000    0.000    0.000    0.000 _ods_common.py:112(get_op_results_or_values)
#       369    0.000    0.000    0.000    0.000 mlir.py:803(set_tokens_out)
#       113    0.000    0.000    0.000    0.000 dtypes.py:287(_scalar_type_to_dtype)
#       129    0.000    0.000    0.000    0.000 core.py:207(__init__)
#        78    0.000    0.000    0.000    0.000 lax.py:2961(_convert_elt_type_fwd_rule)
#        58    0.000    0.000    0.000    0.000 core.py:2574(extend_axis_env)
#        40    0.000    0.000    0.000    0.000 pxla.py:2519(maybe_recover_user_shardings)
#    155/99    0.000    0.000    0.000    0.000 tree_util.py:1135(_generate_key_paths_)
#        20    0.000    0.000    0.001    0.000 pxla.py:2889(<listcomp>)
#        68    0.000    0.000    0.000    0.000 getlimits.py:648(__init__)
#        36    0.000    0.000    0.000    0.000 pjit.py:1344(seen_attrs_get)
#       107    0.000    0.000    0.000    0.000 mlir.py:889(unflatten_ir_values_like_types)
#       390    0.000    0.000    0.000    0.000 batching.py:1070(<genexpr>)
#       175    0.000    0.000    0.000    0.000 pjit.py:2331(keep_where)
#        20    0.000    0.000    0.000    0.000 cache_key.py:254(_hash_xla_flags)
#       149    0.000    0.000    0.000    0.000 core.py:2773(used_axis_names_jaxpr)
# ...
#        37    0.000    0.000    0.000    0.000 mlir.py:1292(<listcomp>)
#        16    0.000    0.000    0.000    0.000 mlir.py:1640(<listcomp>)
#         7    0.000    0.000    0.000    0.000 pxla.py:219(<listcomp>)
#         2    0.000    0.000    0.000    0.000 source_info_util.py:116(transform)
#         1    0.000    0.000    0.000    0.000 lax.py:4796(<listcomp>)
#         1    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         3    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4151(return_)
#         1    0.000    0.000    0.000    0.000 lax.py:5756(_iota_abstract_eval)
#         6    0.000    0.000    0.000    0.000 common.py:40(_abstractify)
#         3    0.000    0.000    0.000    0.000 tree_util.py:790(<lambda>)
#        18    0.000    0.000    0.000    0.000 pjit.py:661(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4840(sign)
#        15    0.000    0.000    0.000    0.000 pxla.py:122(<lambda>)
#         1    0.000    0.000    0.000    0.000 util.py:372(promote_args_inexact)
#        18    0.000    0.000    0.000    0.000 pjit.py:1301(<genexpr>)
#         2    0.000    0.000    0.000    0.000 array.py:1045(_array_mlir_constant_handler)
#        18    0.000    0.000    0.000    0.000 batching.py:872(<genexpr>)
#        12    0.000    0.000    0.000    0.000 slicing.py:284(from_any)
#         3    0.000    0.000    0.000    0.000 conditionals.py:360(<genexpr>)
#         3    0.000    0.000    0.000    0.000 api_util.py:551(_assert_no_intersection)
#         2    0.000    0.000    0.000    0.000 lax.py:2245(_sign_lower_hlo)
#         7    0.000    0.000    0.000    0.000 dtypes.py:677(is_python_scalar)
#        25    0.000    0.000    0.000    0.000 lax.py:2911(_convert_element_type_weak_type_rule)
#         3    0.000    0.000    0.000    0.000 lax.py:4312(<listcomp>)
#        35    0.000    0.000    0.000    0.000 pxla.py:109(identity)
#        18    0.000    0.000    0.000    0.000 api_util.py:293(argnames_partial_except)
#         2    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3402(or_)
#         9    0.000    0.000    0.000    0.000 api_util.py:85(flatten_fun_nokwargs)
#         6    0.000    0.000    0.000    0.000 batching.py:324(flatten_fun_for_vmap)
#         7    0.000    0.000    0.000    0.000 sharding.py:160(devices_indices_map)
#        20    0.000    0.000    0.000    0.000 pxla.py:1785(<listcomp>)
#         1    0.000    0.000    0.000    0.000 array.py:372(__iter__)
#         8    0.000    0.000    0.000    0.000 batching.py:918(<listcomp>)
#         3    0.000    0.000    0.000    0.000 util.py:220(<listcomp>)
#         3    0.000    0.000    0.013    0.004 array_methods.py:421(_transpose_property)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:2746(new_tracer)
#        20    0.000    0.000    0.000    0.000 pxla.py:2103(<genexpr>)
#         1    0.000    0.000    0.000    0.000 loops.py:436(body_fun)
#         2    0.000    0.000    0.000    0.000 loops.py:491(_scan_abstract_eval)
#         1    0.000    0.000    0.000    0.000 array_methods.py:633(<listcomp>)
#         2    0.000    0.000    0.000    0.000 dtypes.py:212(to_numeric_dtype)
#        14    0.000    0.000    0.000    0.000 slicing.py:1606(_dims_in_range)
#        28    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#        18    0.000    0.000    0.000    0.000 pjit.py:784(_flat_axes_specs)
#        25    0.000    0.000    0.000    0.000 lax.py:2907(_convert_element_type_dtype_rule)
#         8    0.000    0.000    0.000    0.000 batching.py:875(<listcomp>)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:1300(<listcomp>)
#         2    0.000    0.000    0.000    0.000 array.py:621(_value)
#         1    0.000    0.000    0.000    0.000 mlir.py:2342(iota)
#         3    0.000    0.000    0.000    0.000 conditionals.py:396(<listcomp>)
#         6    0.000    0.000    0.000    0.000 sharding_impls.py:1139(_check_unique_resources)
#         2    0.000    0.000    0.000    0.000 array_methods.py:1049(op)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:2737(<listcomp>)
#         1    0.000    0.000    0.000    0.000 util.py:365(promote_args_numeric)
#         2    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1601(cosine)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:921(convert_invars_to_constvars)
#        16    0.000    0.000    0.000    0.000 mlir.py:1715(<listcomp>)
#        20    0.000    0.000    0.000    0.000 pxla.py:2115(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cache_key.py:49(get_flag_prefixes)
#         1    0.000    0.000    0.004    0.004 mlir.py:2145(core_call_lowering)
#         4    0.000    0.000    0.000    0.000 lax.py:5014(_argminmax_dtype_rule)
#        12    0.000    0.000    0.000    0.000 tree_util.py:404(<lambda>)
#        20    0.000    0.000    0.000    0.000 compiler.py:70(get_latest_profile_version)
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        16    0.000    0.000    0.000    0.000 slicing.py:1938(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:86(add)
#         6    0.000    0.000    0.000    0.000 pjit.py:1783(<genexpr>)
#         9    0.000    0.000    0.000    0.000 lax.py:1339(<genexpr>)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:5769(_normalize_to_sharding)
#         3    0.000    0.000    0.000    0.000 inspect.py:301(isgeneratorfunction)
#         6    0.000    0.000    0.000    0.000 util.py:378(fun_name)
#         9    0.000    0.000    0.000    0.000 slicing.py:1361(<genexpr>)
#         1    0.000    0.000    0.000    0.000 array_methods.py:631(_unstack)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 tree_util.py:790(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cache_key.py:55(custom_hook)
#         2    0.000    0.000    0.000    0.000 util.py:280(<listcomp>)
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 lax.py:425(add)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3040(iota)
#         2    0.000    0.000    0.000    0.000 batching.py:667(batch)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4085(remainder)
#         2    0.000    0.000    0.000    0.000 lax.py:2364(_cos_lowering)
#        18    0.000    0.000    0.000    0.000 slicing.py:1737(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:177(join_effects)
#         1    0.000    0.000    0.000    0.000 loops.py:444(inner)
#        20    0.000    0.000    0.000    0.000 ad_util.py:82(<lambda>)
#         1    0.000    0.000    0.000    0.000 util.py:262(promote_dtypes_inexact)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3223(maximum)
#         4    0.000    0.000    0.000    0.000 util.py:221(<setcomp>)
#         9    0.000    0.000    0.000    0.000 lax.py:4071(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:106(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:92(_promote_weak_typed_inputs)
#         1    0.000    0.000    0.000    0.000 loops.py:433(cond_fun)
#         2    0.000    0.000    0.000    0.000 functools.py:479(lru_cache)
#         1    0.000    0.000    0.000    0.000 dtypes.py:105(supports_inf)
#         1    0.000    0.000    0.000    0.000 lax.py:1474(_get_min_identity)
#         1    0.000    0.000    0.000    0.000 loops.py:1373(_while_loop_abstract_eval)
#         1    0.000    0.000    0.000    0.000 ufuncs.py:2243(true_divide)
#        12    0.000    0.000    0.000    0.000 core.py:1566(<lambda>)
#         3    0.000    0.000    0.000    0.000 api_util.py:350(rebase_donate_argnums)
#        18    0.000    0.000    0.000    0.000 slicing.py:1738(<genexpr>)
#         1    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         1    0.000    0.000    0.007    0.007 lax.py:385(integer_pow)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(where)
#         6    0.000    0.000    0.000    0.000 api_util.py:466(infer_argnums_and_argnames)
#         1    0.000    0.000    0.000    0.000 lax.py:5800(_iota_lower)
#         2    0.000    0.000    0.000    0.000 lax.py:437(div)
#         1    0.000    0.000    0.000    0.000 lax.py:4798(_reduce_dtype_rule)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:5986(_check_forgot_shape_tuple)
#         2    0.000    0.000    0.000    0.000 util.py:250(<listcomp>)
#        12    0.000    0.000    0.000    0.000 slicing.py:1891(<listcomp>)
#        14    0.000    0.000    0.000    0.000 mlir.py:2365(<lambda>)
#         3    0.000    0.000    0.000    0.000 util.py:412(wraps)
#         8    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 slicing.py:1399(<listcomp>)
#         4    0.000    0.000    0.000    0.000 pjit.py:1784(<genexpr>)
#         1    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         8    0.000    0.000    0.000    0.000 batching.py:876(<listcomp>)
#         4    0.000    0.000    0.000    0.000 api_util.py:427(<listcomp>)
#         2    0.000    0.000    0.000    0.000 lax.py:6110(_abstractify)
#         1    0.000    0.000    0.000    0.000 lax.py:4791(_reduce_shape_rule)
#         1    0.000    0.000    0.000    0.000 lax.py:5779(_iota_staging_rule)
#         2    0.000    0.000    0.000    0.000 lax.py:505(lt)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3255(minimum)
#         1    0.000    0.000    0.000    0.000 tree_util.py:155(treedef_is_leaf)
#         2    0.000    0.000    0.000    0.000 lax.py:409(bitwise_or)
#         1    0.000    0.000    0.000    0.000 lax.py:4808(_reduce_weak_type_rule)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:2738(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:2751(<listcomp>)
#         8    0.000    0.000    0.000    0.000 batching.py:926(<listcomp>)
#         6    0.000    0.000    0.000    0.000 lax.py:4310(<genexpr>)
#         1    0.000    0.000    0.000    0.000 loops.py:922(<listcomp>)
#         1    0.000    0.000    0.000    0.000 util.py:480(__eq__)
#         2    0.000    0.000    0.000    0.000 source_info_util.py:122(__len__)
#         6    0.000    0.000    0.000    0.000 api.py:1017(_get_axis_size)
#         9    0.000    0.000    0.000    0.000 slicing.py:1357(<genexpr>)
#         1    0.000    0.000    0.000    0.000 util.py:269(<listcomp>)
#         3    0.000    0.000    0.000    0.000 inspect.py:199(ismethod)
#         1    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:1665(_dynamic_jaxpr_tracer_shaped_abstractify)
#         6    0.000    0.000    0.000    0.000 pjit.py:375(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax.py:381(pow)
#         6    0.000    0.000    0.000    0.000 lax.py:4595(<genexpr>)
#         1    0.000    0.000    0.000    0.000 utils.py:87(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:4713(<listcomp>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:1567(close_jaxpr)
#         1    0.000    0.000    0.000    0.000 loops.py:1356(_join_while_effects)
#         4    0.000    0.000    0.000    0.000 core.py:2818(typematch)
#         1    0.000    0.000    0.000    0.000 loops.py:481(_stage_jaxpr)
#         3    0.000    0.000    0.000    0.000 functools.py:421(_unwrap_partial)
#         1    0.000    0.000    0.000    0.000 core.py:2414(jaxpr_uses_outfeed)
#         5    0.000    0.000    0.000    0.000 utils.py:77(<genexpr>)
#         5    0.000    0.000    0.000    0.000 lax.py:4889(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pjit.py:1785(<genexpr>)
#         3    0.000    0.000    0.000    0.000 lax.py:5769(<genexpr>)
#         6    0.000    0.000    0.000    0.000 sharding_impls.py:1119(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax.py:405(bitwise_and)
#         1    0.000    0.000    0.000    0.000 lax.py:489(ne)
#         6    0.000    0.000    0.000    0.000 tree_util.py:414(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 tree_util.py:1089(tree_flatten_with_path)
#         1    0.000    0.000    0.000    0.000 lax.py:4892(<listcomp>)
#         1    0.000    0.000    0.000    0.000 array.py:386(is_fully_replicated)
#         2    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.isinstance}
#         3    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 loops.py:973(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:893(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 lax.py:1658(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:4894(<listcomp>)
#         2    0.000    0.000    0.000    0.000 lax.py:5760(<genexpr>)
#         2    0.000    0.000    0.000    0.000 array_methods.py:635(_chunk_iter)
#         3    0.000    0.000    0.000    0.000 conditionals.py:397(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:4800(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:920(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dtypes.py:218(to_inexact_dtype)
#         1    0.000    0.000    0.000    0.000 core.py:2410(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax.py:1659(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:1425(_get_monoid_reducer)
#         1    0.000    0.000    0.000    0.000 lax.py:4801(<listcomp>)
#         2    0.000    0.000    0.000    0.000 core.py:2416(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:4810(<listcomp>)
#         3    0.000    0.000    0.000    0.000 lax.py:4793(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 pjit.py:1786(<genexpr>)
#         1    0.000    0.000    0.000    0.000 partial_eval.py:1809(<listcomp>)
#         4    0.000    0.000    0.000    0.000 lax.py:1989(<lambda>)
#         1    0.000    0.000    0.000    0.000 loops.py:934(<listcomp>)
#         3    0.000    0.000    0.000    0.000 tree_util.py:405(<lambda>)
#         1    0.000    0.000    0.000    0.000 core.py:1641(__ne__)
#         1    0.000    0.000    0.000    0.000 loops.py:439(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:966(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:972(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:1719(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:1419(<genexpr>)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:1812(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:5022(__init__)
#         1    0.000    0.000    0.000    0.000 loops.py:971(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:1785(<listcomp>)
#         2    0.000    0.000    0.000    0.000 multiarray.py:341(where)
#         1    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 loops.py:1718(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:441(<listcomp>)
#         1    0.000    0.000    0.000    0.000 mlir.py:2135(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:926(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:935(<listcomp>)
#         1    0.000    0.000    0.000    0.000 loops.py:1738(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 sharding_impls.py:480(is_fully_replicated)
#         1    0.000    0.000    0.000    0.000 loops.py:1780(<listcomp>)
#         1    0.000    0.000    0.000    0.000 mlir.py:2102(check_backend_matches)

# %%
hp_inner_hp
# Out:
# array([[3528.21411469+0.j, 6749.38881416+0.j],
#        [3528.21411469+0.j, 6749.38881416+0.j],
#        [2045.37526927+0.j, 4030.01160398+0.j]])

# %%
hp_inner_hp[2]
# Out:
# array([2045.37526927+0.j, 4030.01160398+0.j])

# %%
hp_inner_hp
# Out:
# array([[3528.21411469+0.j, 6749.38881416+0.j]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(fs, np.real(hc), label='hc')
plt.plot(fs, np.real(hp), label='hp')

plt.xlim(20, 100)
plt.ylim(-1e-22, 1e-22)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(10, 4))
# ----> 4 plt.plot(fs, np.real(hc), label='hc')
#       5 plt.plot(fs, np.real(hp), label='hp')
#       7 plt.xlim(20, 100)
#
# NameError: name 'fs' is not defined

# %%
from gwsnr import antenna_response_array
# get polarization tensor
# np.shape(Fp) = (size1, len(num_det))
detector_tensor = np.array(gwsnr.detector_tensor_list.copy())
Fp, Fc = antenna_response_array(
    gw_param_dict['ra'], gw_param_dict['dec'], gw_param_dict['geocent_time'], gw_param_dict['psi'], detector_tensor
)
snrs_sq = abs((Fp**2) * hp_inner_hp + (Fc**2) * hc_inner_hc)
snr = np.sqrt(snrs_sq)
snr_effective = np.sqrt(np.sum(snrs_sq, axis=0))

# %%
snr_effective
# Out:
# array([33.20856331,  0.        ])

# %%
import jax
# Test to see if JAX is using the CPU
print("JAX devices:", jax.devices())
# Out:
# JAX devices: [CpuDevice(id=0)]

# %%
from gwsnr import GWSNR

snr = GWSNR(snr_type='inner_product_jax')
# Out:
# psds not given. Choosing bilby's default psds
#
# Chosen GWSNR initialization parameters:
#
# npool:  4
# snr type:  inner_product_jax
# waveform approximant:  IMRPhenomD
# sampling frequency:  2048.0
# minimum frequency (fmin):  20.0
# mtot=mass1+mass2
# min(mtot):  2.0
# max(mtot) (with the given fmin=20.0): 184.98599853446768
# detectors:  ['L1', 'H1', 'V1']
# psds:  [PowerSpectralDensity(psd_file='None', asd_file='/Users/phurailatpamhemantakumar/anaconda3/envs/ripple1/lib/python3.10/site-packages/bilby/gw/detector/noise_curves/aLIGO_O4_high_asd.txt'), PowerSpectralDensity(psd_file='None', asd_file='/Users/phurailatpamhemantakumar/anaconda3/envs/ripple1/lib/python3.10/site-packages/bilby/gw/detector/noise_curves/aLIGO_O4_high_asd.txt'), PowerSpectralDensity(psd_file='None', asd_file='/Users/phurailatpamhemantakumar/anaconda3/envs/ripple1/lib/python3.10/site-packages/bilby/gw/detector/noise_curves/AdV_asd.txt')]

# %%
import numpy as np
size = 1000

gw_param_dict = {
    "mass_1": np.random.uniform(10,50,size),
    "mass_2": np.random.uniform(10,50,size),
    "luminosity_distance": 440*np.ones(size),
    "theta_jn": 0.0*np.ones(size),
    "psi": 0.659*np.ones(size),
    "phase": 0.0*np.ones(size),
    "geocent_time": 0.*np.ones(size),
    "ra": 1.375*np.ones(size),
    "dec": -1.2108*np.ones(size),
    "a_1": 0.5*np.ones(size),
    "a_2": -0.5*np.ones(size),
    "tilt_1": 0.0*np.ones(size),
    "tilt_2": 0.0*np.ones(size),
    "phi_12": 0.0*np.ones(size),
    "phi_jl": 0.0*np.ones(size),
}

idx = (gw_param_dict['mass_1'] < gw_param_dict['mass_2'])
gw_param_dict['mass_1'][idx], gw_param_dict['mass_2'][idx] = gw_param_dict['mass_2'][idx], gw_param_dict['mass_1'][idx]

# %%
# size=20000, time=17.8s 
# size=100000, with for loop 10000X10, 1m 12s
# size=100000, without for loop, inf
for i in range(100):
    result_jax = snr.snr(gw_param_dict=gw_param_dict)
# Out:
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX
# solving SNR with inner product JAX

# %%
#result_jax['optimal_snr_net']

# %%
from gwsnr import GWSNR

snr = GWSNR(snr_type='inner_product')
# Out:
# psds not given. Choosing bilby's default psds
#
# Chosen GWSNR initialization parameters:
#
# npool:  4
# snr type:  inner_product
# waveform approximant:  IMRPhenomD
# sampling frequency:  2048.0
# minimum frequency (fmin):  20.0
# mtot=mass1+mass2
# min(mtot):  2.0
# max(mtot) (with the given fmin=20.0): 184.98599853446768
# detectors:  ['L1', 'H1', 'V1']
# psds:  [PowerSpectralDensity(psd_file='None', asd_file='/Users/phurailatpamhemantakumar/anaconda3/envs/ripple1/lib/python3.10/site-packages/bilby/gw/detector/noise_curves/aLIGO_O4_high_asd.txt'), PowerSpectralDensity(psd_file='None', asd_file='/Users/phurailatpamhemantakumar/anaconda3/envs/ripple1/lib/python3.10/site-packages/bilby/gw/detector/noise_curves/aLIGO_O4_high_asd.txt'), PowerSpectralDensity(psd_file='None', asd_file='/Users/phurailatpamhemantakumar/anaconda3/envs/ripple1/lib/python3.10/site-packages/bilby/gw/detector/noise_curves/AdV_asd.txt')]

# %%
# size=100000, with for loop, 1m 1.0s
result_bilby = snr.compute_bilby_snr(gw_param_dict=gw_param_dict)
# Out:
# 100%|█████████████████████████████████████████████████████| 100000/100000 [01:00<00:00, 1653.18it/s]

# %%
result_bilby['optimal_snr_net']
# Out:
# array([ 77.31933101,  90.77171028,  91.74700759,  66.3794602 ,
#         67.0895219 , 114.40239431,  78.43606522,  70.857959  ,
#         69.07294291,  50.76252381, 100.73894353,  80.06975415,
#         59.16920444,  80.29692442,  93.14666081,  67.86330662,
#         76.38751393, 117.37656027, 106.72251131,  63.42591677,
#         54.69385599,  83.79585122, 101.90275619,  72.37090661,
#         51.5468909 , 120.97855645,  90.46829213, 103.87783013,
#        101.15667436,  59.26054712,  87.30334376,  59.18665181,
#         54.91392879, 106.0821094 ,  66.80762741,  83.31542595,
#         99.33707259,  80.03583806, 118.83693245,  82.40572857,
#         66.93347258,  98.93170276, 107.62912022, 100.57317852,
#         63.04273233,  62.60780267,  95.47219284,  56.40215422,
#         97.25588862,  76.33749737,  60.7396575 ,  97.42932947,
#         65.5618559 ,  64.25346638, 120.80583188,  55.12563456,
#        107.09186324,  60.82863658,  92.84145045,  74.86881584,
#         90.73816493,  93.91424515,  83.77514304, 103.86708925,
#         76.35105064,  63.53842552,  77.18256185, 103.13933142,
#         74.97893895,  84.38497414,  91.40240356,  88.91261849,
#         74.44766254, 105.19566204,  56.85551638,  67.83621144,
#         71.3264952 ,  96.36115639,  61.67400634,  71.99131885,
#        121.26048642,  91.35959602,  82.7242248 , 116.73875847,
#         92.47664158, 104.08249405,  78.78508571,  54.5977305 ,
#         58.02206239,  64.83871459,  67.40824692,  50.06025617,
#         64.67361677,  95.68211448,  98.70840715,  99.59503829,
#         91.06661114,  76.73756096,  53.45824674,  90.59186868,
#         88.28646589,  72.43453795, 103.63958864,  79.48058093,
#         65.59104762,  76.21790846,  93.27008103,  41.95824331,
#         90.02148418,  92.52774356, 110.35142667,  64.97255027,
#         53.43672456,  46.10092365,  60.94059687, 103.06789788,
#         52.32594347,  90.40325466,  60.62101484,  73.32964652,
#         81.86056129,  89.97691877,  84.27456171,  91.01481285,
#         61.82286494,  81.42593966,  79.07883763,  83.6747197 ,
#         75.69775467,  74.90768397,  60.46484152,  79.70114002,
#        106.12610423, 113.90556704,  72.89731853,  80.93269778,
#         60.63690899, 107.61513725,  96.83554517,  53.82319152,
#         66.96108185,  55.21297482,  74.18888134,  71.30032054,
#         67.94187588,  69.06256495, 108.74752635, 121.63416094,
#        100.19115539,  92.34688079,  71.32528436,  60.61660591,
#         77.26083262,  85.16461175,  70.39113736,  60.70273447,
#         80.10239812,  90.75038704,  57.43370597,  59.08123624,
#         94.54137306,  80.73268239,  70.19812853,  50.95739279,
#         80.09660425,  72.10284412,  89.38333471,  92.14802162,
#        105.36624292,  61.50981963,  78.89278379,  71.5902936 ,
#         92.62906579,  42.08847403,  68.20675827,  68.16899074,
#         42.57961736,  69.15416904,  82.38222373, 117.20213743,
#         71.54474817,  85.44058562,  99.82286013,  55.33306836,
#         78.75258431,  86.22752483, 102.76928502, 100.83460878,
#         73.85575853,  70.68249094,  72.89816047,  88.69220204,
#         89.32847005,  77.7107478 ,  68.41634721,  55.92042384,
#         57.15443824,  87.24594012,  90.37439409, 119.38008826,
#         61.36538551,  66.40426484,  76.87091813, 105.88490301,
#        101.41804367,  83.28004708,  55.56324444,  59.81851593,
#         99.48106309,  85.52794723,  82.49345598,  87.16718775,
#        119.35903982,  86.46467639,  96.6985815 ,  77.46608904,
#         64.65791805,  54.59594786,  84.3465114 ,  85.4535472 ,
#        108.46078193, 117.81857526,  74.21265417,  73.03192494,
#        103.65658112,  92.53709837,  61.26112567,  90.57166037,
#        115.67419919,  90.49823685,  73.21238961,  85.38021695,
#         63.32813144,  83.67012584,  80.02382993, 114.76952139,
#        119.07084599, 107.88152491,  63.00479788, 112.28237187,
#         81.55005288,  65.9173844 , 112.15102599,  53.6030039 ,
#         86.55230589,  59.9839968 ,  90.62154819,  73.83623299,
#         95.12127691,  56.01931504, 114.82814937,  50.90310199,
#        105.98959791, 100.85397506, 103.99471633,  52.04626992,
#         55.02457839,  73.28967677,  53.79504673,  74.78864773,
#         67.63086527,  58.14375622, 111.8837843 ,  77.90760758,
#         65.15630825,  51.71377795,  93.24730247,  91.2780294 ,
#         72.06688065,  64.77840655,  68.45759465,  74.60626313,
#         81.69555287,  66.62538525,  56.1141248 ,  78.42856201,
#         93.92555398,  57.41725543,  98.07811126,  47.21929799,
#         93.35151176,  95.08825072,  98.67598781,  73.10583598,
#         81.945211  ,  86.46608411,  54.6251316 ,  91.71668609,
#         84.82662061,  55.87642787,  81.8086695 ,  81.99051961,
#         96.79880534,  66.96623638,  88.27725529,  85.62441217,
#        112.60025503, 114.12011451,  99.93885658, 115.87578981,
#         75.14939634, 117.22188064,  81.36229747,  99.88448395,
#         68.06436839, 112.31268488, 105.97737766,  71.39172696,
#         95.77261131, 109.29319593,  99.09931973,  94.10034427,
#         98.13158642,  94.66300028,  64.86685607, 106.37423301,
#         84.78215056,  93.40876235, 100.01034497,  89.04809042,
#         84.33599092,  86.48509864,  66.19875773,  78.64376453,
#         51.13190791,  84.37830769,  68.00289006,  90.82239619,
#         80.08970582,  66.3995702 ,  61.91578646, 107.46669127,
#        107.60063126,  82.36767296, 105.26144287, 112.3731491 ,
#         98.23467377,  79.27753533,  74.99415655,  56.13026322,
#        101.39608689,  68.08861381,  93.2167035 ,  78.47294894,
#         92.65044715,  57.94824658,  76.89030135,  95.1587182 ,
#         71.51820799,  69.78448925,  93.53982127,  94.49748036,
#         56.40996016,  81.75137776, 120.89383208, 100.93405844,
#         73.30251057, 108.38120283,  80.12423433,  82.57234563,
#        122.42022046,  59.90810794,  82.86761092,  71.27310612,
#         61.40246535, 107.4149325 , 113.12853961,  53.57211703,
#         89.81552991,  55.9300054 ,  98.90822409, 118.21324743,
#         61.79183789,  78.6051667 ,  65.26849232,  71.83712497,
#         89.86782755,  91.08382281,  77.54457377, 113.98134731,
#         66.20039951,  77.53755396,  56.42591956,  66.05736609,
#         89.41447888, 108.00798109, 105.05122784,  81.24250221,
#         72.42826017,  72.33102285, 109.62228353,  76.84199956,
#         80.27678169,  59.79583831,  98.00747427,  83.62700113,
#         57.18702631,  94.21755185,  43.07217293,  69.651843  ,
#        123.48589222, 107.09142926,  52.14882824, 110.47054699,
#         70.5772015 ,  96.09402998,  73.13580886,  65.71989279,
#         83.24132471, 106.2148019 ,  93.98234828,  93.57148044,
#         73.97617779,  58.88210088, 112.95831411,  91.09233867,
#        104.44147226,  90.78348481,  61.90610451,  83.24011639,
#         95.94298288,  50.92226422,  84.24745167,  93.46741533,
#         68.54455872,  74.06207835, 105.86972324,  85.83339481,
#         60.31994205,  71.06176447,  66.30724211,  98.19013375,
#         85.56991278, 108.1130576 , 104.95545883,  64.04834672,
#         65.40909045, 116.79710633,  79.03718531, 115.54934705,
#         57.61691056,  47.67875641,  73.41761857,  74.09059038,
#         57.20867312,  84.44882151,  95.47527634,  98.14734826,
#        107.67673284,  65.10047738,  72.85605952,  91.54572598,
#         72.67955745, 103.63247508,  93.99077332,  98.25015697,
#         72.88226707,  74.85090934,  60.50239629, 101.84821087,
#         78.1415591 , 111.85734211,  97.78822285,  61.21106209,
#         68.39345342,  84.44878424,  66.50861586,  66.13056153,
#         73.20294888,  74.39486932, 111.71331791,  74.55620101,
#         82.01893297,  81.40565169,  94.93498146,  74.18763192,
#         83.57354756,  82.88232436, 109.35706484,  55.95171314,
#         82.14449908,  82.41649728,  73.35527998,  68.79527802,
#         78.83570163, 103.95829003,  77.44270607,  46.92781733,
#         88.71673558,  93.56902584,  78.46202987, 106.31663581,
#         84.4769801 ,  91.11638916,  71.35819173,  50.31422677,
#         81.32046712,  78.77571099,  58.54666246,  74.35591231,
#         70.68858775,  85.35187042,  87.97323834,  40.13701362,
#         64.51861462,  84.20534616,  51.6259732 ,  67.77841608,
#         74.38810497,  68.86612044,  85.41489421,  60.56265791,
#        100.44765363,  87.9274318 ,  99.73372056, 104.16717814,
#         77.8371548 , 105.83465157,  76.04582136,  88.30121764,
#         44.90977348,  64.91973943,  89.73281882,  90.93728705,
#         75.48427075,  98.69306478,  56.04094823,  63.91521064,
#         51.50255806,  97.01946849,  59.55086165,  63.08377275,
#        106.70632686,  57.75836437, 108.7714715 ,  89.63434312,
#         70.79823924,  72.54141115,  73.79420728,  78.77197087,
#         86.91096444,  49.27425917, 111.12756806,  67.34932463,
#        103.25023817,  82.57450002,  53.19109132,  74.2542681 ,
#         77.20361793, 100.54230597,  82.64407706,  90.41265593,
#         76.29428283,  72.86160742,  59.42450007,  70.46281361,
#         77.31838202,  42.11774527, 121.30798627,  75.83577057,
#         65.74271691,  59.04592136,  87.53795011,  60.41578931,
#         91.85521853,  95.72559571, 115.68882242, 107.2957075 ,
#         46.40787878,  71.21473031, 112.4862907 ,  81.43569371,
#         69.83882187, 100.96484098, 104.77958058,  66.59177909,
#        108.13967415,  45.03237102,  45.84265098, 117.42297382,
#         97.45665244,  63.29134482,  71.58990505,  93.41248167,
#         59.87570749,  69.49592592,  71.98655639, 118.98659357,
#         65.85655409,  80.91339007,  67.69234983,  78.20168895,
#        106.50418762,  77.33741116,  76.62917728,  81.14163564,
#         98.07238388,  64.38285875,  73.02494868,  81.67747681,
#         71.82964038,  73.30150893, 103.67638972,  69.21523264,
#        106.8517899 , 109.71080706,  89.83911402,  70.59486372,
#         61.54199914,  91.11921365, 102.97715969,  64.69074581,
#        105.02190512,  55.9350967 ,  47.39869895,  76.6490087 ,
#         58.01539411,  93.80423606,  97.24751222,  63.93470281,
#         71.26965637,  72.30634062,  56.70835288,  78.93043863,
#         95.22177937, 101.85408735,  71.05815361,  73.22587082,
#        109.83802767,  64.33370742,  82.29089216,  79.86306144,
#         46.50074776,  84.25287513,  63.70507133, 102.09116313,
#         95.53181468,  80.81365419,  78.35544424,  63.4706771 ,
#         73.58693741,  67.14254052,  72.50696735,  61.26573968,
#         76.90994478,  60.39352471,  63.89501372,  61.04502971,
#         60.18424854, 115.18089946,  75.25709679,  84.07151206,
#         63.72049008,  54.98392782, 104.28872208, 101.15680679,
#         96.34516687,  70.917324  ,  78.96932092,  63.64037407,
#         77.87927791, 110.15624386,  54.90521828,  75.93833247,
#         70.40657374,  75.98310734,  83.69678894, 110.00701445,
#         57.26333304,  93.65254977, 100.21024588,  59.01860975,
#         52.95670842,  80.94160945,  61.31927948,  42.76591346,
#         56.64209594, 102.04817698,  70.8144293 ,  72.98170406,
#         67.76379882,  67.70764754, 113.62832272, 101.61484491,
#         99.70681086,  76.60919139, 103.51402883,  54.70774091,
#         49.54846026,  68.83525145,  68.31137526,  50.61758105,
#         97.1021787 ,  73.34668079,  88.44900106,  94.6441922 ,
#         99.27546524,  51.38901545,  64.47465453,  71.33580973,
#         93.98462032, 102.27536134, 109.71271835, 101.77395231,
#         99.60936252,  97.24004222,  76.57230931,  53.43836581,
#         92.44232521,  77.71302152,  72.23163592,  87.67468726,
#         63.42162052,  65.37958339,  52.76871276,  89.51521406,
#        109.43566801,  98.81436535,  54.29626638,  69.33934308,
#         59.33184518,  97.3433565 ,  69.20328289,  60.98430089,
#         59.02804937,  86.14242577,  88.82342545,  66.93581349,
#         96.23030406, 110.18124326,  82.63789883,  84.42008963,
#         80.36158165,  70.07508488,  83.42017922,  72.0670832 ,
#        108.40102901,  77.70737619,  70.60822038, 107.01773941,
#         74.50967835,  78.6954061 , 110.82401288,  89.23559747,
#         65.33339865,  75.20412822, 102.13048295,  83.43609752,
#         77.22190834, 114.92595281,  60.21032883,  67.69285587,
#         80.76524944, 103.97137338,  65.80981918,  86.32402533,
#         98.13382914, 104.08602481,  66.78912876,  82.65211015,
#        116.7521899 ,  81.60873985,  80.4812531 ,  44.91144126,
#         71.51447244, 103.71158988,  62.51299039, 112.42872474,
#         61.50192529,  86.98944732,  78.56718587, 104.52130276,
#         71.49821473,  90.04158247,  98.34972547,  55.32599078,
#         76.36546951,  65.50936597,  59.78920839,  83.03079458,
#         47.41854048,  90.29896446,  70.01843572, 119.06910516,
#         87.20366652,  84.98108872,  75.97373649,  96.55467941,
#         84.96015256,  73.86929559,  87.04163985,  88.86561129,
#         95.75500347, 105.10864662,  83.69317564,  82.12082578,
#         85.54575645, 108.75314289, 108.68407002,  61.4100579 ,
#         82.64104767,  77.84052665,  89.36937626, 105.53587295,
#         59.5543885 ,  68.25490266,  65.12840098,  76.24044088,
#         60.93025203, 112.24816954,  72.8774958 ,  62.94472949,
#        102.18921042,  65.05175614, 106.11640763,  76.37028212,
#         83.4709652 ,  80.52286525,  80.46491238,  76.64474679,
#         61.92906316,  81.00441201,  77.24445359,  94.66807193,
#         79.81887698,  94.55856531,  41.91579501,  97.19815712,
#         74.99484129,  61.76735289,  93.23925473, 119.27217982,
#        111.62538585,  56.42572752,  55.97110415,  47.55916263,
#         84.6995037 ,  66.18883937,  74.34713601,  87.07758221,
#         62.77849174, 108.30077543,  88.92421283, 105.74839499,
#         89.15882889,  78.52644439,  53.72158447,  90.40053275,
#         56.33045559,  64.04648198,  92.06009251,  75.25917671,
#         52.22846416, 109.99512473,  76.84331683,  64.13270635,
#        111.06734886,  63.51318334,  94.19397747, 107.08744378,
#         93.68911251,  91.33112345,  77.22340562,  94.47828763,
#         67.51018983,  82.54879006,  69.35133258,  65.05481225,
#         70.91820793, 102.03719657,  53.98357042,  84.36172707,
#         91.94040064, 100.83504745,  53.1449353 ,  99.65420121,
#         54.23692271,  88.00630335, 100.60336438,  97.65432168,
#        114.80005787,  93.07525954,  70.72372606,  62.42346696,
#         87.91145244,  87.93633323,  89.26988472, 109.73445709,
#         79.85878801, 116.94495949,  92.064545  ,  59.94463503,
#         87.35881293, 103.54303666,  54.64793192,  82.22504492,
#        106.87500506,  74.79186734, 110.6339525 ,  88.87837975,
#         74.37883268,  89.22445996,  95.00560625, 117.13116201,
#         64.41765899,  86.49962983, 104.73418676,  78.17345522,
#         67.87706282,  65.95571466,  61.95201683, 120.35859654,
#         93.23273919,  74.09724776,  49.50378108, 117.53010552,
#         60.12523567,  95.66705344,  75.51085792,  69.5838234 ,
#         72.52052493, 104.69450669, 111.57113699,  62.66547027,
#         83.59425249,  81.73534851, 111.70712195, 120.87119877,
#         85.70452057,  71.59522521,  74.14223164,  85.96492471,
#        111.84725685,  78.39662737, 111.59508885,  62.95092913,
#         80.0725656 ,  59.74900783, 105.67855899, 112.6118695 ,
#         96.90085922,  91.76815588, 110.96869739,  78.45341386,
#         73.52075023,  80.2706139 ,  74.30218415,  61.01041176,
#         56.96670595, 100.46883913,  95.74298273,  92.65344138,
#         80.58636911, 109.93273663,  67.62388244, 102.05417993,
#         81.0885961 ,  96.70530484,  96.37491095,  69.95093335,
#        115.5783451 ,  86.00258556,  60.80794622,  69.29713184,
#         72.34510398,  50.96772404,  49.71040049, 116.77506046,
#         83.02502323,  91.01394107,  67.29240244,  75.7933666 ,
#         77.16363786,  70.31687978,  58.28702982, 100.81860798,
#        108.77592169,  81.70709005,  91.03429571,  52.42283608,
#         44.67136113,  79.52665477,  89.65606143,  64.54670925,
#         59.10460043, 102.98499948,  77.69559783,  53.63915845,
#         76.11806337,  92.83885002,  78.32963543,  75.92459864,
#         87.66242408,  61.34828134,  46.36498897,  71.24003502,
#         97.19434227,  86.51056718,  99.06739519,  97.39717594])

# %%
psd_dict = snr[-1]
psd_list = psd_dict['H1']
idx2 = (psd_list != 0.0) & (psd_list != np.inf)

# %%
idx2
# Out:
# Array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
duration = 16.0*np.ones(size)
del_f = 1.0/duration
fs = []
for df  in del_f:
    fs.append(np.arange(test.f_l, test.f_u, df))
# fs = jnp.array(fs)

# %%
import numpy as np

# Example: Including upper limit in the array
start = 0
stop = 5
step = 1.2

# Adjust stop to include the upper limit
arr = np.arange(start, stop + step, step)
print(arr)
# Out:
# [0.  1.2 2.4 3.6 4.8 6. ]

# %%
int((stop-start)/step)+1
# Out:
# 5

# %%
len(arr)
# Out:
# 6
